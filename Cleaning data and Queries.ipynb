# %%
# import pyspark functions
from pyspark.sql.functions import *
# import URL processing
import urllib
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls("/FileStore/tables")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [FileInfo(path=&#39;dbfs:/FileStore/tables/authentication_credentials.csv&#39;, name=&#39;authentication_credentials.csv&#39;, size=202, modificationTime=1687110999000)]</div>

# %%
# Specify file type to be csv
file_type = "csv"
# Indicates file has first row as the header
first_row_is_header = "true"
# Indicates file has comma as the delimeter
delimiter = ","
# Read the CSV file to spark dataframe
aws_keys_df = spark.read.format(file_type)\
.option("header", first_row_is_header)\
.option("sep", delimiter)\
.load("/FileStore/tables/authentication_credentials.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Get the AWS access key and secret key from the spark dataframe
ACCESS_KEY = aws_keys_df.where(col('User name')=='databricks-user').select('Access key ID').collect()[0]['Access key ID']
SECRET_KEY = aws_keys_df.where(col('User name')=='databricks-user').select('Secret access key').collect()[0]['Secret access key']
# Encode the secrete key
ENCODED_SECRET_KEY = urllib.parse.quote(string=SECRET_KEY, safe="")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# AWS S3 bucket name
AWS_S3_BUCKET = "user-0af8d0adfd13-bucket"
# Mount name for the bucket
MOUNT_NAME = "/mnt/user-0af8d0adfd13-bucket"
# Source url
SOURCE_URL = "s3n://{0}:{1}@{2}".format(ACCESS_KEY, ENCODED_SECRET_KEY, AWS_S3_BUCKET)
# Mount the drive
dbutils.fs.mount(SOURCE_URL, MOUNT_NAME)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4016701205644569&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span> SOURCE_URL <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;s3n://{0}:{1}@{2}&#34;</span><span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span>ACCESS_KEY<span class="ansi-blue-fg">,</span> ENCODED_SECRET_KEY<span class="ansi-blue-fg">,</span> AWS_S3_BUCKET<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span> <span class="ansi-red-fg"># Mount the drive</span>
# <span class="ansi-green-fg">----&gt; 8</span><span class="ansi-red-fg"> </span>dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>mount<span class="ansi-blue-fg">(</span>SOURCE_URL<span class="ansi-blue-fg">,</span> MOUNT_NAME<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python_shell/dbruntime/dbutils.py</span> in <span class="ansi-cyan-fg">f_with_exception_handling</span><span class="ansi-blue-fg">(*args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    387</span>                     exc<span class="ansi-blue-fg">.</span>__context__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    388</span>                     exc<span class="ansi-blue-fg">.</span>__cause__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-fg">--&gt; 389</span><span class="ansi-red-fg">                     </span><span class="ansi-green-fg">raise</span> exc
# <span class="ansi-green-intense-fg ansi-bold">    390</span>
# <span class="ansi-green-intense-fg ansi-bold">    391</span>             <span class="ansi-green-fg">return</span> f_with_exception_handling
#
# <span class="ansi-red-fg">ExecutionError</span>: An error occurred while calling o418.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/user-0af8d0adfd13-bucket; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/user-0af8d0adfd13-bucket
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:128)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:68)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.createOrUpdateMount(DBUtilsCore.scala:756)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.mount(DBUtilsCore.scala:776)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:750)
# Caused by: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/user-0af8d0adfd13-bucket
# 	at scala.Predef$.require(Predef.scala:281)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.$anonfun$insertMount$1(MetadataManager.scala:601)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.$anonfun$modifyAndVerify$2(MetadataManager.scala:977)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.withRetries(MetadataManager.scala:750)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.modifyAndVerify(MetadataManager.scala:966)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.insertMount(MetadataManager.scala:609)
# 	at com.databricks.backend.daemon.data.server.handler.MountHandler.receive(MountHandler.scala:120)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.$anonfun$queryHandlers$1(SessionContext.scala:54)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.$anonfun$queryHandlers$1$adapted(SessionContext.scala:53)
# 	at scala.collection.immutable.List.foreach(List.scala:431)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.queryHandlers(SessionContext.scala:53)
# 	at com.databricks.backend.daemon.data.server.DbfsServerBackend$$anonfun$receive$4.$anonfun$applyOrElse$5(DbfsServerBackend.scala:386)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:426)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:424)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:418)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:472)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:455)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:22)
# 	at com.databricks.backend.daemon.data.server.DbfsServerBackend$$anonfun$receive$4.applyOrElse(DbfsServerBackend.scala:386)
# 	at com.databricks.backend.daemon.data.server.DbfsServerBackend$$anonfun$receive$4.applyOrElse(DbfsServerBackend.scala:332)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:174)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:200)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:200)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:171)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$1(ServerBackend.scala:147)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:573)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:668)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:686)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:426)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:424)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:418)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:472)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:455)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:663)
# 	at com.databricks.logging.UsageLogging.r

# %% [markdown]
# Show the files in the topics directory

# %%
display(dbutils.fs.ls("/mnt/user-0af8d0adfd13-bucket/topics"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
######## This was used for test purposes only

# # File location and type
# # Asterisk(*) indicates reading all the content of the specified file that have .json extension
# file_location = "/mnt/user-0af8d0adfd13-bucket/topics/0af8d0adfd13.geo/partition=0/*.json" 
# # you need to remember to put in the partition=0 bit!
# file_type = "json"
# # Ask Spark to infer the schema
# infer_schema = "true"
# # Read in JSONs from mounted S3 bucket
# df = spark.read.format(file_type) \
# .option("inferSchema", infer_schema) \
# .load(file_location)
# # Display Spark dataframe to check its content
# display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Tests with PySpark
#
# Use df.count() to return the total number of rows in the PySpark DataFrame. This function triggers all transformations on the DataFrame to execute.
#
# Use df.distinct().count() to find the number of unique rows in the PySpark DataFrame.
#
# Use len(df.columns) to get the number of columns in the DataFrame.
#
# You can also get the column count using len(df.dtypes) by retrieving all column names and data types as a list of tuples and applying len() on the list.
#
# To count null values in columns, you can use functions like count(when(isnan(column) | col(column).isNull(), column)) for each column to find the number of null, None, or NaN values.
#
# For counting values in a column, use pyspark.sql.functions.count(column) to count non-null values in a specific column. It ignores null/none values.
#
# pyspark.sql.functions.col
#
# Returns a Column based on the given column name.

# %%
# country_df = df.select("country").distinct()
# country_df.show(250)



# df_user.show()
# type(df_user)

#dftest = df_user.distinct()
#dftest.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# print(f"The number of individual countries is: {country_df.count()}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# country_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# starts_with_a = country_df.filter(country_df["country"].rlike("^[aA].*"))
# starts_with_a.show()

## test

# df = spark.read.format("json").option("inferSchema", False).load("/mnt/user-0af8d0adfd13-bucket/alternative/pinterest_data.json")

# df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Filtering
# https://sparkbyexamples.com/spark/spark-dataframe-where-to-filter-rows/

# %% [markdown]
# -----------------------------------

# %% [markdown]
# Functions

# %%
# lets make this a function

def make_dataframe(table_name):
    ''' Makes a dataframe for each of the data buckets in the S3 bucket for pin, geo and user
    
    Argument:   table_name (string)

    Returns:    dataframe
    '''
    # Asterisk(*) indicates reading all the content of the specified file that have .json extension
    file_location = f"/mnt/user-0af8d0adfd13-bucket/topics/0af8d0adfd13.{table_name}/partition=0/*.json" 
    # you need to remember to put in the partition=0 bit!
    file_type = "json"
    # Ask Spark to infer the schema
    infer_schema = "true"
    # Read in JSONs from mounted S3 bucket
    df = spark.read.format(file_type) \
    .option("inferSchema", infer_schema) \
    .load(file_location)
    # Display Spark dataframe to check its content
    # display(df)
    return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pin = make_dataframe("pin")  #for the Pinterest post data
df_geo = make_dataframe("geo")  #for the geolocation data
df_user = make_dataframe("user") #for the user data.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Data Cleaning for df_pin

# %%
def clean_column(df, column_name, string, debug=True): # default to None for replacement
    ''' cleans a column of a dataframe, using the LIKE string format. Removes the entire entry and replaces with None
    Arguments:
        df: DataFrame
        column_name: string
        string: string formatted as a LIKE condition
        debug: shows state of the table before and after
    
    '''

    if (debug):
        df.groupBy(column_name).count().orderBy('count', ascending=False).show()
        
    df_temp = df_pin.withColumn(column_name,when(df_pin[column_name].like(string), None).otherwise(df_pin[column_name])) 
    
    if (debug):
        df_temp.groupBy(column_name).count().orderBy('count', ascending=False).show()
        
    return df_temp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pin = clean_column(df_pin, "description", "No description available%")
df_pin = clean_column(df_pin, "follower_count", "User Info Error%")
df_pin = clean_column(df_pin, "image_src", "Image src error%") # prob need to use a regex to keep the right ones here
df_pin = clean_column(df_pin, "save_location", "%.jpg") # still need to have a strategy for random text - need a negative somewhere
df_pin = clean_column(df_pin, "tag_list", "N,o, ,T,a,g,s,%")
df_pin = clean_column(df_pin, "title", "No Title Data%")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#          description|count|
# +--------------------+-----+
# No description av...|  113|
# No description av...|   23|
# Our mission at K&amp;...|    8|
# Relationship Rule...|    5|
# Imagine your birt...|    4|
# Out with the old,...|    3|
# 35 European bucke...|    3|
# Glossier Turns 4:...|    3|
# Do you love plann...|    3|
# Macho Moda: Blog ...|    3|
# Top Apps for Even...|    3|
# Gli studenti dell...|    3|
# Use our easy step...|    3|
# Free quick inspir...|    3|
# Showing the lates...|    3|
# Over 40 of the BE...|    3|
# Study the art of ...|    3|
# It doesn&#39;t matter...|    3|
# It&#39;s time to re-d...|    3|
# Are you looking f...|    3|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#          description|count|
# +--------------------+-----+
#                 null|  136|
# Our mission at K&amp;...|    8|
# Relationship Rule...|    5|
# Imagine your birt...|    4|
# Over 40 of the BE...|    3|
# Study the art of ...|    3|
# It doesn&#39;t matter...|    3|
# Gli studenti dell...|    3|
# Glossier Turns 4:...|    3|
# It&#39;s time to re-d...|    3|
# Top Apps for Even...|    3|
# Do you love plann...|    3|
# Are you looking f...|    3|
# Tattoos are one o...|    3|
# Use our easy step...|    3|
# Macho Moda: Blog ...|    3|
# Out with the old,...|    3|
# 35 European bucke...|    3|
# Free quick inspir...|    3|
# Showing the lates...|    3|
# +--------------------+-----+
# only showing top 20 rows
#
# +---------------+-----+
#  follower_count|count|
# +---------------+-----+
#              2M|   48|
#              5k|   43|
#              3k|   39|
#              4k|   39|
#              1k|   38|
#              2k|   36|
#              7k|   33|
#            942k|   29|
#              6k|   28|
#              1M|   22|
#              9k|   22|
#              8k|   20|
#              5M|   19|
#             13k|   18|
#             19k|   17|
#             11k|   17|
#             20k|   17|
# User Info Error|   17|
#             10k|   16|
#             28k|   14|
# +---------------+-----+
# only showing top 20 rows
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#             2M|   48|
#             5k|   43|
#             3k|   39|
#             4k|   39|
#             1k|   38|
#             2k|   36|
#             7k|   33|
#           942k|   29|
#             6k|   28|
#             1M|   22|
#             9k|   22|
#             8k|   20|
#             5M|   19|
#            13k|   18|
#            11k|   17|
#            20k|   17|
#            19k|   17|
#           null|   17|
#            10k|   16|
#           500k|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#            image_src|count|
# +--------------------+-----+
#     Image src error.|   38|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#            image_src|count|
# +--------------------+-----+
#                 null|   38|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
# Local save in /da...|  161|
# Local save in /da...|  151|
# Local save in /da...|  135|
# Local save in /da...|  132|
# Local save in /da...|  129|
# Local save in /da...|  129|
# Local save in /da...|  126|
# Local save in /da...|  122|
# Local save in /da...|  116|
# Local save in /da...|  114|
# Local save in /da...|  107|
# Local save in /da...|  102|
# Local save in /da...|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
# Local save in /da...|  161|
# Local save in /da...|  151|
# Local save in /da...|  135|
# Local save in /da...|  132|
# Local save in /da...|  129|
# Local save in /da...|  129|
# Local save in /da...|  126|
# Local save in /da...|  122|
# Local save in /da...|  116|
# Local save in /da...|  114|
# Local save in /da...|  107|
# Local save in /da...|  102|
# Local save in /da...|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#             tag_list|count|
# +--------------------+-----+
# N,o, ,T,a,g,s, ,A...|   27|
# Collage Kunst,Pap...|    3|
# Art History Lesso...|    3|
# Home Decor Kitche...|    3|
# Fake People Quote...|    3|
# Dream Tattoos,Bod...|    3|
# Luxury Sports Car...|    3|
# Crush Quotes For ...|    3|
# Backpacking Europ...|    3|
# Classroom Art Pro...|    2|
# Handprint Christm...|    2|
# Winter Home Decor...|    2|
# Best Armor,Armore...|    2|
# African Art Proje...|    2|
# Ways To Save Mone...|    2|
# Homemade Skin Car...|    2|
# Rooms Home Decor,...|    2|
# Greek Islands To ...|    2|
# Adventure Aesthet...|    2|
# Torre Eiffel Pari...|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#             tag_list|count|
# +--------------------+-----+
#                 null|   27|
# Fake People Quote...|    3|
# Luxury Sports Car...|    3|
# Home Decor Kitche...|    3|
# Art History Lesso...|    3|
# Collage Kunst,Pap...|    3|
# Crush Quotes For ...|    3|
# Dream Tattoos,Bod...|    3|
# Backpacking Europ...|    3|
# Classroom Art Pro...|    2|
# Handprint Christm...|    2|
# Winter Home Decor...|    2|
# Best Armor,Armore...|    2|
# African Art Proje...|    2|
# Ways To Save Mone...|    2|
# Homemade Skin Car...|    2|
# Rooms Home Decor,...|    2|
# Greek Islands To ...|    2|
# Adventure Aesthet...|    2|
# Torre Eiffel Pari...|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#                title|count|
# +--------------------+-----+
# No Title Data Ava...|   17|
# Over 40 of the BE...|    3|
# Silhouette su sfo...|    3|
# 18 Daily Motivati...|    3|
# Top Apps for Even...|    3|
# How to Work From ...|    3|
# 25 Ultra Sexy Bac...|    3|
# 30 Unique Bedroom...|    3|
# Top 10 Home Decor...|    3|
# DIY Abstract Hear...|    3|
# 50 Heart Touching...|    3|
# Cobba | Non-stop ...|    3|
# The Artists and t...|    3|
# Men&#39;s Fashion for...|    3|
# Best Tattoos For ...|    3|
# Quotes - Two Sout...|    3|
# Sports Cars: Pric...|    3|
# creating mixed-me...|    3|
# European Bucket L...|    3|
# Gingerbread House...|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#                title|count|
# +--------------------+-----+
#                 null|   17|
# Over 40 of the BE...|    3|
# Silhouette su sfo...|    3|
# 18 Daily Motivati...|    3|
# Top Apps for Even...|    3|
# How to Work From ...|    3|
# Best Tattoos For ...|    3|
# 30 Unique Bedroom...|    3|
# Top 10 Home Decor...|    3|
# creating mixed-me...|    3|
# Cobba | Non-stop ...|    3|
# DIY Abstract Hear...|    3|
# Men&#39;s Fashion for...|    3|
# Sports Cars: Pric...|    3|
# The Artists and t...|    3|
# 25 Ultra Sexy Bac...|    3|
# Quotes - Two Sout...|    3|
# 50 Heart Touching...|    3|
# European

# %%
def clean_column_regex(df, column_name, regex, replacement, debug=True):
     ''' Replaces the regex the supplied element

     Arguments:
          df: Dataframe
          column_name: string
          regex: regular expression
          replacement: string

     Returns: Dataframe
     '''
     
     if (debug):
          df.groupBy(column_name).count().orderBy('count', ascending=False).show() # we should use a decorator for this. LET'S DO THIS!!

     df_temp = df_pin.withColumn(column_name, regexp_replace(column_name, regex, replacement)) 

     if (debug):
          df_temp.groupBy(column_name).count().orderBy('count', ascending=False).show()

     return df_temp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pin = clean_column_regex(df_pin, "save_location", "Local save in ", "") 
df_pin = clean_column_regex(df_pin, "follower_count", "[kK]", "000") 
df_pin = clean_column_regex(df_pin, "follower_count", "[mM]", "000000")
df_pin = df_pin.withColumn("follower_count", df_pin.follower_count.cast("int"))
#df_pin = df_pin.withColumn("index", df_pin.follower_count.cast("int")) # convert to int for index, as was string

clean_column(df_pin, "save_location", "%pinimg%")
clean_column(df_pin, "save_location", "image")

df_pin.printSchema()
df_pin
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#        save_location|count|
# +--------------------+-----+
# Local save in /da...|  161|
# Local save in /da...|  151|
# Local save in /da...|  135|
# Local save in /da...|  132|
# Local save in /da...|  129|
# Local save in /da...|  129|
# Local save in /da...|  126|
# Local save in /da...|  122|
# Local save in /da...|  116|
# Local save in /da...|  114|
# Local save in /da...|  107|
# Local save in /da...|  102|
# Local save in /da...|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#             2M|   48|
#             5k|   43|
#             3k|   39|
#             4k|   39|
#             1k|   38|
#             2k|   36|
#             7k|   33|
#           942k|   29|
#             6k|   28|
#             1M|   22|
#             9k|   22|
#             8k|   20|
#             5M|   19|
#            13k|   18|
#            11k|   17|
#            20k|   17|
#            19k|   17|
#           null|   17|
#            10k|   16|
#           500k|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#             2M|   48|
#           5000|   43|
#           3000|   39|
#           4000|   39|
#           1000|   38|
#           2000|   36|
#           7000|   33|
#         942000|   29|
#           6000|   28|
#             1M|   22|
#           9000|   22|
#           8000|   20|
#             5M|   19|
#          13000|   18|
#          20000|   17|
#          11000|   17|
#          19000|   17|
#           null|   17|
#          10000|   16|
#          28000|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#             2M|   48|
#           5000|   43|
#           3000|   39|
#           4000|   39|
#           1000|   38|
#           2000|   36|
#           7000|   33|
#         942000|   29|
#           6000|   28|
#             1M|   22|
#           9000|   22|
#           8000|   20|
#             5M|   19|
#          13000|   18|
#          20000|   17|
#          11000|   17|
#          19000|   17|
#           null|   17|
#          10000|   16|
#          28000|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#        2000000|   48|
#           5000|   43|
#           3000|   39|
#           4000|   39|
#           1000|   38|
#           2000|   36|
#           7000|   33|
#         942000|   29|
#           6000|   28|
#        1000000|   22|
#           9000|   22|
#           8000|   20|
#        5000000|   19|
#          13000|   18|
#          11000|   17|
#          20000|   17|
#          19000|   17|
#           null|   17|
#          10000|   16|
#          28000|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# root
# -- index: long (nullable = true)
# -- unique_id: string (nullable = true)
# -- title: string (nullable = true)
# -- description: string (nullable = true)
# -- follower_count: integer (nullable = true)
# -- poster_name: string (nullable = true)
# -- tag_list: string (nullable = true)
# -- is_image_or_video: string (nullable = true)
# -- image_src: string (nullable = true)
# -- save_location: string (nullable = true)
# -- category: string (nullable = true)
#
# Out[13]: DataFrame[index: bigint, unique_id: string, title: string, description: string, follower_count: int, poster_name: string, tag_list: string, is_image_or_video: string, image_src: string, save_location: string, category: string]</div>

# %%
df_pin.printSchema
df_pin.filter(~df_pin.save_location.rlike('\/\w+')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;bound method DataFrame.printSchema of DataFrame[index: bigint, unique_id: string, title: string, description: string, follower_count: int, poster_name: string, tag_list: string, is_image_or_video: string, image_src: string, save_location: string, category: string]&gt;
# +-----+---------+-----+-----------+--------------+-----------+--------+-----------------+---------+-------------+--------+
# index|unique_id|title|description|follower_count|poster_name|tag_list|is_image_or_video|image_src|save_location|category|
# +-----+---------+-----+-----------+--------------+-----------+--------+-----------------+---------+-------------+--------+
# +-----+---------+-----+-----------+--------------+-----------+--------+-----------------+---------+-------------+--------+
#
# </div>

# %%
df_pin.filter(df_pin.save_location.rlike('\/\w+')).show(300)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------+-------------------------------------+-------------------------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# index|           unique_id|                                title|                          description|follower_count|         poster_name|            tag_list|is_image_or_video|           image_src|       save_location|      category|
# +-----+--------------------+-------------------------------------+-------------------------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
#  4387|ae5e7377-f1bd-4ac...|                 Βάπτιση: H παραμυ...|                 Το όνομα που επέλ...|             4|Manosbojana Katsa...|Diy Flowers,Flowe...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  6717|bc5ab9ee-505e-44f...|                〚 Уютные шведские...|                 Традиционные швед...|        136000|PUFIK Interiors &amp;...|Scandinavian Cott...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
#  4858|58101415-9273-431...|                 THE EVENT COLLECT...|                 15.1k Likes, 83 C...|           311|      Marie Bradford|Diy Birthday Deco...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  4608|d234e56f-5b18-4ef...|                 Virtual Baby Show...|                 Wow your guests! ...|          1000|Iconica Design | ...|Christmas Party B...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  6633|d136f6bc-840d-44f...|                 The Cottage Journ...|                 6,636 Likes, 141 ...|           394|        Sarah Martin|Diy Kitchen Cabin...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
#  1706|b5c8a1b5-9e90-452...|                 Standing Figurine...|                 Features: Materia...|          5000|            Wear24-7|Merry Christmas T...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  1706|b5c8a1b5-9e90-452...|                 Standing Figurine...|                 Features: Materia...|          5000|            Wear24-7|Merry Christmas T...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  1676|3ed92c2d-9cca-4cc...|                 PAUPOO™ Pre-lit A...|                 ❤️ ❤️ MERRY CHRIS...|           784|              paupoo|Christmas Hanging...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  2482|08604f20-fa17-4b9...|                 FORNT PORCH CHRIS...|                 Christmas decorat...|         46000|Life on Summerhil...|Diy Christmas Dec...|            video|https://i.pinimg....|     /data/christmas|     christmas|
#  2482|08604f20-fa17-4b9...|                 FORNT PORCH CHRIS...|                 Christmas decorat...|         46000|Life on Summerhil...|Diy Christmas Dec...|            video|https://i.pinimg....|     /data/christmas|     christmas|
#  2057|883542eb-d365-403...|                 Green/White Pine ...|                 Sick of sweeping ...|          5000|            Wear24-7|Christmas Garden,...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  4712|0eb5569f-0130-455...|                 My Big Day Market...|                 Creative Events i...|         10000|My Big Day Market...|Fall Wedding,Drea...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  2430|7e16143b-d84a-40a...|                 9ft Lighted Winte...|                 About This Item W...|          5000|            Wear24-7|Outside Christmas...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  4348|c25f8906-d9ab-414...|                 Surprise Birthday...|                 &#34;adult Surprise B...|       4000000|                Etsy|90th Birthday Car...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  6521|dd508c7e-4ff3-4a9...|                 Allan Copley Desi...|                 Description The C...|           137|Your Home, Reimag...|Glass Top End Tab...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
#  6521|dd508c7e-4ff3-4a9...|                 Allan Copley Desi...|                 Description The C...|           137|Your Home, Reimag...|Glass Top End Tab...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
# 10538|5d9fa7e2-2118-444...|                 BC Customs (BCC) ...|                 By David Crane ; ...|           709|           Ricky Lee|Army Vehicles,Arm...|            image|https://i.pinimg....|      /data/vehicles|      vehicles|
#  4585|aa873546-701b-40d...|                 She Attaches Crys...|                 This fabulous DIY...|        985000|DIY Joy - Crafts,...|Cheap Favors,Wedd...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#   527|ed8af037-ee87-4a8...|                 Blue Gold Marble ...|                 Marble Wall Art M...|           305|    Wall Canvas Mall|Modern Art Painti...|            image|https://i.pinimg....|           /data/art|           art|
#  4547|7120db4c-3d59-464...|                 Day of Coordinati...|                 Day of Coordinati...|          4000|Arenlace Bride Bo...|Wedding Vendors,W...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  4547|7120db4c-3d59-464...|                 Day of Coordinati...|                 Day of Coordinati...|          4000|Arenlace Bride Bo...|Wedding Vendors,W...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  2732|800c4f90-50aa-4e3...|                 Gingerbread Man P...|                 Make this cute an...|        267000|Easy Kids Crafts ...|Gingerbread Man C...|            image|https://i.pinimg....|/data/diy-and-crafts|diy-and-crafts|
#  8699|91c61561-068b-479...|                 @chik.tattoo on I...|                 Avis au intéressé...|          2000|        NoitaDesigns|Hand Tattoos,Love...|            image|https://i.pinimg....|       /data/tattoos|       tattoos|
#  4357|ccf116e9-9096-494...|                 First Steps in La...|                 Updated: January ...|          4000|EventPlanning.com...|Event Planning Qu...|            image|https://i.pinimg....|/data/event-planning|event-planning|
# 10379|9d48e180-aa78-48e...|                 Новая легкая брон...|                 На проходящей в П...|           336|      Dominic Shoblo|Lifted Ford Truck...|            image|https://i.pinimg....|      /data/vehicles|      vehicles|
#  4925|662c77cd-d99a-45f...|                 20FT x 10FT Blush...|                 20ftx10ft Blush D...|         68000|eFavormart | One-...|Pink Photography,...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  2237|81186814-b77a-4cd...|                 30 Cheap Christma...|                 I am ready to dec...|         53000|Happily Ever Afte...|Winter Wedding Ce...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  1944|cf35cd49-3b77-413...|                 120 Frugal Christ...|                 Decorate for Chri...|        647000|Prudent Penny Pin...|Cheap Christmas G...|            video|https://i.pinimg....|     /data/christmas|     christmas|
#  2288|991f5083-e4f2-4ee...|                 97 Farmhouse Chri...|                 All the farmhouse...|         91000|Kristen | Lifesty...|Christmas Decorat...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  4489|e52a6409-1c00-461...|                 VINTAGE WEDDING P...|

# %% [markdown]
# Looking for garbage values

# %%
df_pin.filter(df_pin.isNull()).show()
print(df_pin.filter(df_pin.isNull()).count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2497017771562130&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>df_pin<span class="ansi-blue-fg">.</span>filter<span class="ansi-blue-fg">(</span>df_pin<span class="ansi-blue-fg">.</span>isNull<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> print<span class="ansi-blue-fg">(</span>df_pin<span class="ansi-blue-fg">.</span>filter<span class="ansi-blue-fg">(</span>df_pin<span class="ansi-blue-fg">.</span>isNull<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">__getattr__</span><span class="ansi-blue-fg">(self, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1798</span>         &#34;&#34;&#34;
# <span class="ansi-green-intense-fg ansi-bold">   1799</span>         <span class="ansi-green-fg">if</span> name <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">in</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 1800</span><span class="ansi-red-fg">             raise AttributeError(
# </span><span class="ansi-green-intense-fg ansi-bold">   1801</span>                 &#34;&#39;%s&#39; object has no attribute &#39;%s&#39;&#34; % (self.__class__.__name__, name))
# <span class="ansi-green-intense-fg ansi-bold">   1802</span>         jc <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>apply<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;DataFrame&#39; object has no attribute &#39;isNull&#39;</div>

# %%
df_pin.filter(df_pin.save_location.rlike('\/\w+')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------+---------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# index|           unique_id|                title|         description|follower_count|         poster_name|            tag_list|is_image_or_video|           image_src|       save_location|      category|
# +-----+--------------------+---------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
#  4387|ae5e7377-f1bd-4ac...| Βάπτιση: H παραμυ...|Το όνομα που επέλ...|             4|Manosbojana Katsa...|Diy Flowers,Flowe...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  6717|bc5ab9ee-505e-44f...|〚 Уютные шведские...|Традиционные швед...|        136000|PUFIK Interiors &amp;...|Scandinavian Cott...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
#  4858|58101415-9273-431...| THE EVENT COLLECT...|15.1k Likes, 83 C...|           311|      Marie Bradford|Diy Birthday Deco...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  4608|d234e56f-5b18-4ef...| Virtual Baby Show...|Wow your guests! ...|          1000|Iconica Design | ...|Christmas Party B...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  6633|d136f6bc-840d-44f...| The Cottage Journ...|6,636 Likes, 141 ...|           394|        Sarah Martin|Diy Kitchen Cabin...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
#  1706|b5c8a1b5-9e90-452...| Standing Figurine...|Features: Materia...|          5000|            Wear24-7|Merry Christmas T...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  1706|b5c8a1b5-9e90-452...| Standing Figurine...|Features: Materia...|          5000|            Wear24-7|Merry Christmas T...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  1676|3ed92c2d-9cca-4cc...| PAUPOO™ Pre-lit A...|❤️ ❤️ MERRY CHRIS...|           784|              paupoo|Christmas Hanging...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  2482|08604f20-fa17-4b9...| FORNT PORCH CHRIS...|Christmas decorat...|         46000|Life on Summerhil...|Diy Christmas Dec...|            video|https://i.pinimg....|     /data/christmas|     christmas|
#  2482|08604f20-fa17-4b9...| FORNT PORCH CHRIS...|Christmas decorat...|         46000|Life on Summerhil...|Diy Christmas Dec...|            video|https://i.pinimg....|     /data/christmas|     christmas|
#  2057|883542eb-d365-403...| Green/White Pine ...|Sick of sweeping ...|          5000|            Wear24-7|Christmas Garden,...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  4712|0eb5569f-0130-455...| My Big Day Market...|Creative Events i...|         10000|My Big Day Market...|Fall Wedding,Drea...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  2430|7e16143b-d84a-40a...| 9ft Lighted Winte...|About This Item W...|          5000|            Wear24-7|Outside Christmas...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  4348|c25f8906-d9ab-414...| Surprise Birthday...|&#34;adult Surprise B...|       4000000|                Etsy|90th Birthday Car...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  6521|dd508c7e-4ff3-4a9...| Allan Copley Desi...|Description The C...|           137|Your Home, Reimag...|Glass Top End Tab...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
#  6521|dd508c7e-4ff3-4a9...| Allan Copley Desi...|Description The C...|           137|Your Home, Reimag...|Glass Top End Tab...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
# 10538|5d9fa7e2-2118-444...| BC Customs (BCC) ...|By David Crane ; ...|           709|           Ricky Lee|Army Vehicles,Arm...|            image|https://i.pinimg....|      /data/vehicles|      vehicles|
#  4585|aa873546-701b-40d...| She Attaches Crys...|This fabulous DIY...|        985000|DIY Joy - Crafts,...|Cheap Favors,Wedd...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#   527|ed8af037-ee87-4a8...| Blue Gold Marble ...|Marble Wall Art M...|           305|    Wall Canvas Mall|Modern Art Painti...|            image|https://i.pinimg....|           /data/art|           art|
#  4547|7120db4c-3d59-464...| Day of Coordinati...|Day of Coordinati...|          4000|Arenlace Bride Bo...|Wedding Vendors,W...|            image|https://i.pinimg....|/data/event-planning|event-planning|
# +-----+--------------------+---------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# I think we might need to reindex after moving the columns

# %%
# #TODO Extra cleaning

# df_pin.groupBy('save_location').count().orderBy('count', ascending=False).show()
# df_pin = clean_column_regex(df_pin, "save_location", "(http).*", 'None')
# clean_column(df_pin, "save_location", "None")
# df_pin.groupBy('save_location').count().orderBy('count', ascending=False).show()

# %%
#dbutils.fs.unmount("/mnt/user-0af8d0adfd13-bucket") # not sure if this will stop everything working, or if we just read from the S3 and the storage is on Databricks. YES IT DOES STOP EVERYTHING
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
display(df_geo)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
display(df_pin)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
display(df_user)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# df_pin["category"].distinct().show()
df.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# To clean the df_pin DataFrame you should perform the following transformations:
#
# - Replace empty entries and entries with no relevant data in each column with Nones
# - Perform the necessary transformations on the follower_count to ensure every entry is a number. Make sure the data type of this column is an int.
# - Ensure that each column containing numeric data has a numeric data type
# - Clean the data in the save_location column to include only the save location path
# - Rename the index column to ind.
# - Reorder the DataFrame columns to have the following column order:
#   - ind
#   - unique_id
#   - title
#   - description
#   - follower_count
#   - poster_name
#   - tag_list
#   - is_image_or_video
#   - image_src
#   - save_location
#   - category

# %% [markdown]
# ## Data Exploration of df_pin

# %%
df_pin.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
for c in df_pin.columns:
    df_temp = df_pin.select(c).distinct()
    print(f"{c} has {df_temp.count()} unique elements")
    df_temp.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Temporarily use Pandas for data exploration, and then write the data cleaning code in PySpark

# %%
import pandas as pd

df_pin_pandas = df_pin.toPandas()

df_pin_pandas.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
for c in df_pin_pandas:
    temp_df = df_pin_pandas[df_pin_pandas[c] == ""]
    print(f"{c} has {temp_df[c].count()} empty bits")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
count_empty = df_pin.filter(df_pin.category == "");
print(count_empty.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#Replace empty entries and entries with no relevant data in each column with Nones
print(df_pin.count())

for column in df_pin.columns:
    df_pin.withColumn(column, when(col(column)=="", None))



# Perform the necessary transformations on the follower_count to ensure every entry is a number. Make sure the data type of this column is an int.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# #### Perform the necessary transformations on the follower_count to ensure every entry is a number. Make sure the data type of this column is an int.

# %%
# There are some ks in this file, and maybe other things. Perhaps we need to explore it first to see everything that is not a number. Let's do this in pandas.

display(df_pin_pandas[df_pin_pandas['follower_count'].str.contains('[^0-9]', regex=True)])

## so we see 'k', which we need to strip. User Info Error should be replaced with NULL in the previous entry.

temp_df = df_pin_pandas[df_pin_pandas['follower_count'].str.contains('[a-zA-Z]|[0-9]*[a-zA-Z]', regex=True)]
temp_df['follower_count'].unique()

# So we need to change User Info Error to numpy.na (although that doesn't work for ints). Hmm
# We also need to multiply any k with 1000, an M by 1000000 and then remove the k and M
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df_pin.groupBy('follower_count').count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Let's go through all columns in df_pin and identify the garbage values, if any, that occur more frequently

for column in df_pin.columns:
    df_pin.groupBy(column).count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# check more for save_location
df_pin.groupBy('save_location').count().orderBy('count', ascending=False).show(100, False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# description:  "No description available" x 2 (need to investigate more)
#
# follower_count: "User Info Error"
#
# image_src: "Image src error."
#
# save_location: We have "Local save in " and then the pathname. Let's see if that all there is, because those are just the top values
#
# tag_list: "N,o, ,T,a,g,s, ,A"...
#
# title: "No Title Data" etc

# %%
# TODO: learn most efficient way to do replacing values in a column
# TODO: incorporate this into a function to clean the df_pin table.
# TODO: convert k and m into 1000 and 1000000 respectively
# TODO: clean up the "Save location" 
# TODO: change name of ind to index
# TODO: change the order of the columns

# Having issues with None and regex_replace
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.replace.html
# https://stackoverflow.com/questions/37038014/pyspark-replace-strings-in-spark-dataframe-column#:~:text=The%20function%20withColumn%20is%20called,substrings%20that%20match%20the%20pattern.



def replace_with(df, column, regular_expression, replaced):
    df.groupBy(column).count().orderBy('count', ascending=False).show()
    # df_pin_temp = df_pin.withColumn('description', regexp_replace('description', 'No description available[\W\w]*', None))
    df_temp = df_pin.withColumn(column, regexp_replace(column, regular_expression, None))
    df_temp.groupBy(column).count().orderBy('count', ascending=False).show()
    return df_temp


df_temp = replace_with(df_pin, 'category', 'beaut', None)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df_pin
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: DataFrame[index: bigint, unique_id: string, title: string, description: string, follower_count: int, poster_name: string, tag_list: string, is_image_or_video: string, image_src: string, save_location: string, category: string]</div>

# %%
df_pin.createOrReplaceTempView("pin_table")
df_geo.createOrReplaceTempView('geo_table')
df_user.createOrReplaceTempView('user_table')
result = spark.sql("SELECT * FROM pin_table")
result.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------+---------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# index|           unique_id|                title|         description|follower_count|         poster_name|            tag_list|is_image_or_video|           image_src|       save_location|      category|
# +-----+--------------------+---------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
#  4387|ae5e7377-f1bd-4ac...| Βάπτιση: H παραμυ...|Το όνομα που επέλ...|             4|Manosbojana Katsa...|Diy Flowers,Flowe...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  6717|bc5ab9ee-505e-44f...|〚 Уютные шведские...|Традиционные швед...|        136000|PUFIK Interiors &amp;...|Scandinavian Cott...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
#  4858|58101415-9273-431...| THE EVENT COLLECT...|15.1k Likes, 83 C...|           311|      Marie Bradford|Diy Birthday Deco...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  4608|d234e56f-5b18-4ef...| Virtual Baby Show...|Wow your guests! ...|          1000|Iconica Design | ...|Christmas Party B...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  6633|d136f6bc-840d-44f...| The Cottage Journ...|6,636 Likes, 141 ...|           394|        Sarah Martin|Diy Kitchen Cabin...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
#  1706|b5c8a1b5-9e90-452...| Standing Figurine...|Features: Materia...|          5000|            Wear24-7|Merry Christmas T...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  1706|b5c8a1b5-9e90-452...| Standing Figurine...|Features: Materia...|          5000|            Wear24-7|Merry Christmas T...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  1676|3ed92c2d-9cca-4cc...| PAUPOO™ Pre-lit A...|❤️ ❤️ MERRY CHRIS...|           784|              paupoo|Christmas Hanging...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  2482|08604f20-fa17-4b9...| FORNT PORCH CHRIS...|Christmas decorat...|         46000|Life on Summerhil...|Diy Christmas Dec...|            video|https://i.pinimg....|     /data/christmas|     christmas|
#  2482|08604f20-fa17-4b9...| FORNT PORCH CHRIS...|Christmas decorat...|         46000|Life on Summerhil...|Diy Christmas Dec...|            video|https://i.pinimg....|     /data/christmas|     christmas|
#  2057|883542eb-d365-403...| Green/White Pine ...|Sick of sweeping ...|          5000|            Wear24-7|Christmas Garden,...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  4712|0eb5569f-0130-455...| My Big Day Market...|Creative Events i...|         10000|My Big Day Market...|Fall Wedding,Drea...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  2430|7e16143b-d84a-40a...| 9ft Lighted Winte...|About This Item W...|          5000|            Wear24-7|Outside Christmas...|            image|https://i.pinimg....|     /data/christmas|     christmas|
#  4348|c25f8906-d9ab-414...| Surprise Birthday...|&#34;adult Surprise B...|       4000000|                Etsy|90th Birthday Car...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#  6521|dd508c7e-4ff3-4a9...| Allan Copley Desi...|Description The C...|           137|Your Home, Reimag...|Glass Top End Tab...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
#  6521|dd508c7e-4ff3-4a9...| Allan Copley Desi...|Description The C...|           137|Your Home, Reimag...|Glass Top End Tab...|            image|https://i.pinimg....|    /data/home-decor|    home-decor|
# 10538|5d9fa7e2-2118-444...| BC Customs (BCC) ...|By David Crane ; ...|           709|           Ricky Lee|Army Vehicles,Arm...|            image|https://i.pinimg....|      /data/vehicles|      vehicles|
#  4585|aa873546-701b-40d...| She Attaches Crys...|This fabulous DIY...|        985000|DIY Joy - Crafts,...|Cheap Favors,Wedd...|            image|https://i.pinimg....|/data/event-planning|event-planning|
#   527|ed8af037-ee87-4a8...| Blue Gold Marble ...|Marble Wall Art M...|           305|    Wall Canvas Mall|Modern Art Painti...|            image|https://i.pinimg....|           /data/art|           art|
#  4547|7120db4c-3d59-464...| Day of Coordinati...|Day of Coordinati...|          4000|Arenlace Bride Bo...|Wedding Vendors,W...|            image|https://i.pinimg....|/data/event-planning|event-planning|
# +-----+--------------------+---------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ## Task 1: Clean the Dataframe that contains information about Pinterest posts
#
# To clean the df_pin DataFrame you should perform the following transformations:
#
# - Replace empty entries and entries with no relevant data in each column with Nones ✅ --> but still some tinkering to do
# - Perform the necessary transformations on the follower_count to ensure every entry is a number. Make sure the data type of this column is an int. ✅
# - Ensure that each column containing numeric data has a numeric data type ✅
# - Clean the data in the save_location column to include only the save location path
# - Rename the index column to ind. ✅
# - Reorder the DataFrame columns to have the following column order:✅
#   - ind
#   - unique_id
#   - title
#   - description
#   - follower_count
#   - poster_name
#   - tag_list
#   - is_image_or_video
#   - image_src
#   - save_location
#   - category

# %%
def clean_column(df, column_name, string, debug=True): # default to None for replacement
    ''' cleans a column of a dataframe, using the LIKE string format. Removes the entire entry and replaces with None
    Arguments:
        df: DataFrame
        column_name: string
        string: string formatted as a LIKE condition
        debug: shows state of the table before and after
    
    '''

    if (debug):
        df.groupBy(column_name).count().orderBy('count', ascending=False).show() # use a decorator for this
        
    df_temp = df_pin.withColumn(column_name,when(df_pin[column_name].like(string), None).otherwise(df_pin[column_name])) 
    
    if (debug):
        df_temp.groupBy(column_name).count().orderBy('count', ascending=False).show()
        
    return df_temp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pin = clean_column(df_pin, "description", "No description available%")
df_pin = clean_column(df_pin, "follower_count", "User Info Error%")
df_pin = clean_column(df_pin, "image_src", "Image src error%") # prob need to use a regex to keep the right ones here
df_pin = clean_column(df_pin, "save_location", "%.jpg") # still need to have a strategy for random text - need a negative somewhere
df_pin = clean_column(df_pin, "tag_list", "N,o, ,T,a,g,s,%")
df_pin = clean_column(df_pin, "title", "No Title Data%")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#          description|count|
# +--------------------+-----+
#                 null|  136|
# Our mission at K&amp;...|    8|
# Relationship Rule...|    5|
# Imagine your birt...|    4|
# Tattoos are one o...|    3|
# Top Apps for Even...|    3|
# Over 40 of the BE...|    3|
# Study the art of ...|    3|
# Gli studenti dell...|    3|
# Do you love plann...|    3|
# It doesn&#39;t matter...|    3|
# Out with the old,...|    3|
# 35 European bucke...|    3|
#     matte black benz|    3|
# Glossier Turns 4:...|    3|
# Macho Moda: Blog ...|    3|
# Use our easy step...|    3|
# Free quick inspir...|    3|
# It&#39;s time to re-d...|    3|
# Are you looking f...|    3|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#          description|count|
# +--------------------+-----+
#                 null|  136|
# Our mission at K&amp;...|    8|
# Relationship Rule...|    5|
# Imagine your birt...|    4|
# Tattoos are one o...|    3|
# Top Apps for Even...|    3|
# Over 40 of the BE...|    3|
# Study the art of ...|    3|
# Gli studenti dell...|    3|
# Do you love plann...|    3|
# It doesn&#39;t matter...|    3|
# Out with the old,...|    3|
# 35 European bucke...|    3|
#     matte black benz|    3|
# Glossier Turns 4:...|    3|
# Macho Moda: Blog ...|    3|
# Use our easy step...|    3|
# Free quick inspir...|    3|
# It&#39;s time to re-d...|    3|
# Are you looking f...|    3|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#        2000000|   48|
#           5000|   43|
#           3000|   39|
#           4000|   39|
#           1000|   38|
#           2000|   36|
#           7000|   33|
#         942000|   29|
#           6000|   28|
#        1000000|   22|
#           9000|   22|
#           8000|   20|
#        5000000|   19|
#          13000|   18|
#          20000|   17|
#          11000|   17|
#          19000|   17|
#           null|   17|
#          10000|   16|
#          28000|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#        2000000|   48|
#           5000|   43|
#           3000|   39|
#           4000|   39|
#           1000|   38|
#           2000|   36|
#           7000|   33|
#         942000|   29|
#           6000|   28|
#        1000000|   22|
#           9000|   22|
#           8000|   20|
#        5000000|   19|
#          13000|   18|
#          20000|   17|
#          11000|   17|
#          19000|   17|
#           null|   17|
#          10000|   16|
#          28000|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#            image_src|count|
# +--------------------+-----+
#                 null|   38|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#            image_src|count|
# +--------------------+-----+
#                 null|   38|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    3|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# https://i.pinimg....|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#             tag_list|count|
# +--------------------+-----+
#                 null|   27|
# Home Decor Kitche...|    3|
# Crush Quotes For ...|    3|
# Backpacking Europ...|    3|
# Collage Kunst,Pap...|    3|
# Fake People Quote...|    3|
# Dream Tattoos,Bod...|    3|
# Luxury Sports Car...|    3|
# Art History Lesso...|    3|
# Literacy Games,Ki...|    2|
# Upper Middle Clas...|    2|
# African Art Proje...|    2|
# Top Travel Destin...|    2|
# Diy Christmas Lig...|    2|
# Dainty Tattoos,Ba...|    2|
# Noel Christmas,Di...|    2|
# Life Quotes Love,...|    2|
# Our Wedding,Weddi...|    2|
# Natural Hair Mask...|    2|
# Farmhouse Christm...|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#             tag_list|count|
# +--------------------+-----+
#                 null|   27|
# Art History Lesso...|    3|
# Home Decor Kitche...|    3|
# Collage Kunst,Pap...|    3|
# Fake People Quote...|    3|
# Dream Tattoos,Bod...|    3|
# Luxury Sports Car...|    3|
# Backpacking Europ...|    3|
# Crush Quotes For ...|    3|
# Costa Rica Travel...|    2|
# Beautiful Places ...|    2|
# Party Planning Ch...|    2|
# Family Vacation D...|    2|
# Vacation Places,D...|    2|
# Merry Christmas T...|    2|
# Middle School Cla...|    2|
# Investing In Stoc...|    2|
# Christmas Gifts F...|    2|
# Art And Illustrat...|    2|
# Winter Activities...|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#                title|count|
# +--------------------+-----+
#                 null|   17|
# Top 10 Home Decor...|    3|
# DIY Abstract Hear...|    3|
# 18 Daily Motivati...|    3|
# 30 Unique Bedroom...|    3|
# Top Apps for Even...|    3|
# The Artists and t...|    3|
# Men&#39;s Fashion for...|    3|
# European Bucket L...|    3|
# Over 40 of the BE...|    3|
# Cobba | Non-stop ...|    3|
# 25 Ultra Sexy Bac...|    3|
# Best Tattoos For ...|    3|
# Quotes - Two Sout...|    3|
# Silhouette su sfo...|    3|
# 50 Heart Touching...|    3|
# creating mixed-me...|    3|
# Sports Cars: Pric...|    3|
# How to Work From ...|    3|
# 67 Fantasy And Me...|    2|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#                title|count|
# +--------------------+-----+
#                 null|   17|
# Over 40 of the BE...|    3|
# DIY Abstract Hear...|    3|
# 18 Daily Motivati...|    3|
# Silhouette su sfo...|    3|
# 30 Unique Bedroom...|    3|
# European Bucket L...|    3|
# Cobba | Non-stop ...|    3|
# The Artists and t...|    3|
# 25 Ultra Sexy Bac...|    3|
# Best Tattoos For ...|    3|
# Quotes - Two Sout...|    3|
# Sports Cars: Pric...|    3|
# Top 10 Home Decor...|    3|
# How to Work From ...|    3|
# 50 Heart Touching...|    3|
# creating mixed-me...|    3|
# Men&#39;s Fashion for...|    3|
# Top Apps for Even...|    3|
# 21 Be

# %%
def clean_column_regex(df, column_name, regex, replacement, debug=True):
     ''' Replaces the regex the supplied element

     Arguments:
          df: Dataframe
          column_name: string
          regex: regular expression
          replacement: string

     Returns: Dataframe
     '''
     
     if (debug):
          df.groupBy(column_name).count().orderBy('count', ascending=False).show() # we should use a decorator for this. LET'S DO THIS!!

     df_temp = df_pin.withColumn(column_name, regexp_replace(column_name, regex, replacement)) 

     if (debug):
          df_temp.groupBy(column_name).count().orderBy('count', ascending=False).show()

     return df_temp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pin = clean_column_regex(df_pin, "save_location", "Local save in ", "") 
df_pin = clean_column_regex(df_pin, "follower_count", "[kK]", "000") 
df_pin = clean_column_regex(df_pin, "follower_count", "[mM]", "000000")
df_pin = df_pin.withColumn("follower_count", df_pin.follower_count.cast("int"))
# df_pin = df_pin.withColumn("index", df_pin.follower_count.cast("int")) # convert to int for index, as was string

clean_column(df_pin, "save_location", "%pinimg%")
clean_column(df_pin, "save_location", "image")

df_pin.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#        2000000|   48|
#           5000|   43|
#           3000|   39|
#           4000|   39|
#           1000|   38|
#           2000|   36|
#           7000|   33|
#         942000|   29|
#           6000|   28|
#        1000000|   22|
#           9000|   22|
#           8000|   20|
#        5000000|   19|
#          13000|   18|
#          20000|   17|
#          11000|   17|
#          19000|   17|
#           null|   17|
#          10000|   16|
#         500000|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#        2000000|   48|
#           5000|   43|
#           3000|   39|
#           4000|   39|
#           1000|   38|
#           2000|   36|
#           7000|   33|
#         942000|   29|
#           6000|   28|
#        1000000|   22|
#           9000|   22|
#           8000|   20|
#        5000000|   19|
#          13000|   18|
#          19000|   17|
#          20000|   17|
#          11000|   17|
#           null|   17|
#          10000|   16|
#              5|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#        2000000|   48|
#           5000|   43|
#           3000|   39|
#           4000|   39|
#           1000|   38|
#           2000|   36|
#           7000|   33|
#         942000|   29|
#           6000|   28|
#        1000000|   22|
#           9000|   22|
#           8000|   20|
#        5000000|   19|
#          13000|   18|
#          11000|   17|
#          20000|   17|
#          19000|   17|
#           null|   17|
#          10000|   16|
#          28000|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------+-----+
# follower_count|count|
# +--------------+-----+
#        2000000|   48|
#           5000|   43|
#           3000|   39|
#           4000|   39|
#           1000|   38|
#           2000|   36|
#           7000|   33|
#         942000|   29|
#           6000|   28|
#        1000000|   22|
#           9000|   22|
#           8000|   20|
#        5000000|   19|
#          13000|   18|
#          20000|   17|
#          11000|   17|
#          19000|   17|
#           null|   17|
#          10000|   16|
#          28000|   14|
# +--------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# +--------------------+-----+
#        save_location|count|
# +--------------------+-----+
#      /data/christmas|  161|
#            /data/art|  151|
#         /data/quotes|  135|
#         /data/travel|  132|
#   /data/mens-fashion|  129|
#        /data/finance|  129|
#      /data/education|  126|
# /data/diy-and-crafts|  122|
#        /data/tattoos|  116|
# /data/event-planning|  114|
#       /data/vehicles|  107|
#     /data/home-decor|  102|
#         /data/beauty|   99|
# +--------------------+-----+
#
# root
# -- ind: long (nullable = true)
# -- unique_id: string (nullable = true)
# -- title: string (nullable = true)
# -- description: string (nullable = true)
# -- follower_count: integer (nullable = true)
# -- poster_name: string (nullable = true)
# -- tag_list: string (nullable = true)
# -- is_image_or_video: string (nullable = true)
# -- image_src: string (nullable = true)
# -- save_location: string (nullable = true)
# -- category: string (nullable = true)
#
# </div>

# %%
###################START HERE AGAIN
#################################
df_pin = df_pin.withColumnRenamed('index', 'ind') # change name
df_pin = df_pin.select("ind", "unique_id", "title", "description", "follower_count", "poster_name", "tag_list", "is_image_or_video", "image_src", "save_location", "category") # change order
df_pin.printSchema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[80]: &lt;bound method DataFrame.printSchema of DataFrame[ind: bigint, unique_id: string, title: string, description: string, follower_count: int, poster_name: string, tag_list: string, is_image_or_video: string, image_src: string, save_location: string, category: string]&gt;</div>

# %% [markdown]
# NEED TO INSERT THE TASK 2 and TASK 3 cleanign code

# %% [markdown]
# ## Task 2: Clean the Dataframe that contains information about geolocation
#
# To clean the df_geo DataFrame you should perform the following transformations:
#
# - Create a new column coordinates that contains an array based on the latitude and longitude columns
# - Drop the latitude and longitude columns from the DataFrame
# - Convert the timestamp column from a string to a timestamp data type
# - Reorder the DataFrame columns to have the following column order:
#   - ind
#   - country
#   - coordinates
#   - timestamp

# %%
from pyspark.sql.functions import *

# df_geo = df_geo.withColumn("coordinates", concat(df_geo["latitude"], ', ', df_geo["longitude"])) needs to be an array

df_geo = df_geo.select(df_geo.ind, df_geo.country ,array(df_geo.latitude, df_geo.longitude).alias("coordinates"), df_geo.timestamp)
df_geo = df_geo.withColumn("timestamp", to_timestamp("timestamp"))
df_geo.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ind: long (nullable = true)
# -- country: string (nullable = true)
# -- coordinates: array (nullable = false)
#     |-- element: double (containsNull = true)
# -- timestamp: timestamp (nullable = true)
#
# </div>

# %% [markdown]
# ## Task 3: Clean the Dataframe that contains information about Users
#
# To clean the df_user DataFrame you should perform the following transformations:
#
# - Create a new column user_name that concatenates the information found in the first_name and last_name columns
# - Drop the first_name and last_name columns from the DataFrame
# - Convert the date_joined column from a string to a timestamp data type
# - Reorder the DataFrame columns to have the following column order:
#   - ind
#   - user_name
#   - age
#   - date_joined

# %%
df_user = df_user.withColumn("user_name", concat(df_user["first_name"], lit(" "), df_user["last_name"]))
df_user = df_user.drop('first_name', 'last_name')
df_user = df_user.withColumn("date_joined", to_timestamp("date_joined"))
df_user = df_user.select(df_user.ind, df_user.user_name, df_user.age, df_user.date_joined)
df_user.printSchema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[83]: &lt;bound method DataFrame.printSchema of DataFrame[ind: bigint, user_name: string, age: bigint, date_joined: timestamp]&gt;</div>

# %%
# %sql
-- this doesn't work
-- WITH order_table AS(
--   SELECT date, item, sales, sum(sales)
--     OVER ( PARTITION BY (item) ORDER BY sales DESC ROWS BETWEEN unbounded PRECEDING AND CURRENT ROW) cumsum
--   FROM sales_table
-- ) 

-- SELECT date, item, FIRST(sales)
--   OVER ( PARTITION BY (date) )
-- FROM order_table
-- GROUP BY date, item, sales


-- SELECT DISTINCT country ,--ON (country) country,
--     category,
--     count
-- FROM (
--         SELECT country,
--             category,
--             count(*) AS count
--         FROM pin_table
--             JOIN geo_table ON geo_table.ind = pin_table.index
--         GROUP BY country,
--             category
--         ORDER BY country,
--             count DESC
--     )
-- ORDER BY country,
--     count DESC NULLS LAST;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>category</th><th>count</th></tr></thead><tbody><tr><td>Afghanistan</td><td>education</td><td>19</td></tr><tr><td>Afghanistan</td><td>quotes</td><td>11</td></tr><tr><td>Afghanistan</td><td>finance</td><td>7</td></tr><tr><td>Afghanistan</td><td>mens-fashion</td><td>6</td></tr><tr><td>Afghanistan</td><td>diy-and-crafts</td><td>5</td></tr><tr><td>Afghanistan</td><td>home-decor</td><td>3</td></tr><tr><td>Afghanistan</td><td>vehicles</td><td>3</td></tr><tr><td>Afghanistan</td><td>christmas</td><td>2</td></tr><tr><td>Afghanistan</td><td>tattoos</td><td>2</td></tr><tr><td>Afghanistan</td><td>art</td><td>2</td></tr><tr><td>Afghanistan</td><td>event-planning</td><td>2</td></tr><tr><td>Afghanistan</td><td>travel</td><td>1</td></tr><tr><td>Albania</td><td>art</td><td>29</td></tr><tr><td>Albania</td><td>mens-fashion</td><td>13</td></tr><tr><td>Albania</td><td>education</td><td>12</td></tr><tr><td>Albania</td><td>beauty</td><td>11</td></tr><tr><td>Albania</td><td>diy-and-crafts</td><td>10</td></tr><tr><td>Albania</td><td>quotes</td><td>8</td></tr><tr><td>Albania</td><td>christmas</td><td>8</td></tr><tr><td>Albania</td><td>home-decor</td><td>5</td></tr><tr><td>Albania</td><td>tattoos</td><td>5</td></tr><tr><td>Albania</td><td>finance</td><td>3</td></tr><tr><td>Albania</td><td>travel</td><td>2</td></tr><tr><td>Albania</td><td>event-planning</td><td>1</td></tr><tr><td>Albania</td><td>vehicles</td><td>1</td></tr><tr><td>Algeria</td><td>quotes</td><td>35</td></tr><tr><td>Algeria</td><td>travel</td><td>10</td></tr><tr><td>Algeria</td><td>mens-fashion</td><td>10</td></tr><tr><td>Algeria</td><td>tattoos</td><td>7</td></tr><tr><td>Algeria</td><td>finance</td><td>5</td></tr><tr><td>Algeria</td><td>art</td><td>4</td></tr><tr><td>Algeria</td><td>christmas</td><td>2</td></tr><tr><td>Algeria</td><td>home-decor</td><td>1</td></tr><tr><td>Algeria</td><td>beauty</td><td>1</td></tr><tr><td>Algeria</td><td>event-planning</td><td>1</td></tr><tr><td>American Samoa</td><td>travel</td><td>10</td></tr><tr><td>American Samoa</td><td>education</td><td>10</td></tr><tr><td>American Samoa</td><td>tattoos</td><td>9</td></tr><tr><td>American Samoa</td><td>art</td><td>9</td></tr><tr><td>American Samoa</td><td>beauty</td><td>6</td></tr><tr><td>American Samoa</td><td>christmas</td><td>4</td></tr><tr><td>American Samoa</td><td>diy-and-crafts</td><td>2</td></tr><tr><td>American Samoa</td><td>quotes</td><td>2</td></tr><tr><td>American Samoa</td><td>home-decor</td><td>1</td></tr><tr><td>American Samoa</td><td>mens-fashion</td><td>1</td></tr><tr><td>Andorra</td><td>tattoos</td><td>9</td></tr><tr><td>Andorra</td><td>christmas</td><td>6</td></tr><tr><td>Andorra</td><td>art</td><td>5</td></tr><tr><td>Andorra</td><td>quotes</td><td>4</td></tr><tr><td>Andorra</td><td>vehicles</td><td>3</td></tr><tr><td>Andorra</td><td>event-planning</td><td>3</td></tr><tr><td>Andorra</td><td>diy-and-crafts</td><td>3</td></tr><tr><td>Andorra</td><td>education</td><td>3</td></tr><tr><td>Andorra</td><td>home-decor</td><td>1</td></tr><tr><td>Andorra</td><td>beauty</td><td>1</td></tr><tr><td>Andorra</td><td>mens-fashion</td><td>1</td></tr><tr><td>Angola</td><td>diy-and-crafts</td><td>7</td></tr><tr><td>Angola</td><td>education</td><td>4</td></tr><tr><td>Angola</td><td>art</td><td>2</td></tr><tr><td>Angola</td><td>beauty</td><td>2</td></tr><tr><td>Angola</td><td>home-decor</td><td>1</td></tr><tr><td>Angola</td><td>event-planning</td><td>1</td></tr><tr><td>Angola</td><td>travel</td><td>1</td></tr><tr><td>Anguilla</td><td>diy-and-crafts</td><td>8</td></tr><tr><td>Anguilla</td><td>home-decor</td><td>6</td></tr><tr><td>Anguilla</td><td>beauty</td><td>6</td></tr><tr><td>Anguilla</td><td>christmas</td><td>2</td></tr><tr><td>Anguilla</td><td>tattoos</td><td>1</td></tr><tr><td>Anguilla</td><td>event-planning</td><td>1</td></tr><tr><td>Anguilla</td><td>education</td><td>1</td></tr>< ...

# %% [markdown]
# ### QUERIES

# %%
# create views to query the data using SQL

df_pin.createOrReplaceTempView("pin_table")
df_geo.createOrReplaceTempView('geo_table')
df_user.createOrReplaceTempView('user_table')
result = spark.sql("SELECT * FROM pin_table")
result.show()

# %% [markdown]
# THIS ONE WORKS!!!!!!
#
# ###TASK 4: Find the most popular Pinterest category people post to based on their country.
#
#
# Your query should return a DataFrame that contains the following columns:
#
# country
# category
# category_count, a new column containing the desired query output

# %%
# First we need to create views which the SQL can access
df_pin.createOrReplaceTempView("pin_table")
df_geo.createOrReplaceTempView('geo_table')
df_user.createOrReplaceTempView('user_table')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
WITH join_tables AS (
  SELECT country,
  category,
  count(*) AS count
  FROM pin_table
      JOIN geo_table ON geo_table.ind = pin_table.ind
  GROUP BY country,
           category

),
get_rank AS (
  SELECT country, 
  category, 
  count, 
  RANK () OVER (
    PARTITION BY country
    ORDER BY count DESC
  ) cat_rank
FROM 
  join_tables
)
SELECT DISTINCT country, 
  category, 
  count
FROM 
  get_rank
WHERE 
  cat_rank=1


  -- ORDER BY country,
  --     count DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>category</th><th>count</th></tr></thead><tbody><tr><td>Afghanistan</td><td>education</td><td>19</td></tr><tr><td>Albania</td><td>art</td><td>29</td></tr><tr><td>Algeria</td><td>quotes</td><td>35</td></tr><tr><td>American Samoa</td><td>travel</td><td>10</td></tr><tr><td>American Samoa</td><td>education</td><td>10</td></tr><tr><td>Andorra</td><td>tattoos</td><td>9</td></tr><tr><td>Angola</td><td>diy-and-crafts</td><td>7</td></tr><tr><td>Anguilla</td><td>diy-and-crafts</td><td>8</td></tr><tr><td>Antarctica (the territory South of 60 deg S)</td><td>christmas</td><td>7</td></tr><tr><td>Antarctica (the territory South of 60 deg S)</td><td>tattoos</td><td>7</td></tr><tr><td>Antigua and Barbuda</td><td>art</td><td>7</td></tr><tr><td>Argentina</td><td>tattoos</td><td>15</td></tr><tr><td>Armenia</td><td>diy-and-crafts</td><td>9</td></tr><tr><td>Aruba</td><td>christmas</td><td>13</td></tr><tr><td>Australia</td><td>mens-fashion</td><td>9</td></tr><tr><td>Austria</td><td>travel</td><td>10</td></tr><tr><td>Azerbaijan</td><td>finance</td><td>11</td></tr><tr><td>Bahamas</td><td>art</td><td>11</td></tr><tr><td>Bahrain</td><td>travel</td><td>5</td></tr><tr><td>Bangladesh</td><td>christmas</td><td>12</td></tr><tr><td>Barbados</td><td>travel</td><td>10</td></tr><tr><td>Belarus</td><td>travel</td><td>2</td></tr><tr><td>Belgium</td><td>diy-and-crafts</td><td>5</td></tr><tr><td>Belize</td><td>diy-and-crafts</td><td>8</td></tr><tr><td>Benin</td><td>finance</td><td>2</td></tr><tr><td>Benin</td><td>travel</td><td>2</td></tr><tr><td>Benin</td><td>tattoos</td><td>2</td></tr><tr><td>Bermuda</td><td>christmas</td><td>10</td></tr><tr><td>Bhutan</td><td>finance</td><td>2</td></tr><tr><td>Bhutan</td><td>diy-and-crafts</td><td>2</td></tr><tr><td>Bhutan</td><td>event-planning</td><td>2</td></tr><tr><td>Bolivia</td><td>diy-and-crafts</td><td>4</td></tr><tr><td>Bolivia</td><td>home-decor</td><td>4</td></tr><tr><td>Bosnia and Herzegovina</td><td>education</td><td>4</td></tr><tr><td>Botswana</td><td>tattoos</td><td>10</td></tr><tr><td>Bouvet Island (Bouvetoya)</td><td>travel</td><td>4</td></tr><tr><td>Brazil</td><td>finance</td><td>2</td></tr><tr><td>British Indian Ocean Territory (Chagos Archipelago)</td><td>diy-and-crafts</td><td>1</td></tr><tr><td>British Indian Ocean Territory (Chagos Archipelago)</td><td>mens-fashion</td><td>1</td></tr><tr><td>British Indian Ocean Territory (Chagos Archipelago)</td><td>finance</td><td>1</td></tr><tr><td>British Indian Ocean Territory (Chagos Archipelago)</td><td>tattoos</td><td>1</td></tr><tr><td>British Virgin Islands</td><td>christmas</td><td>9</td></tr><tr><td>Brunei Darussalam</td><td>education</td><td>1</td></tr><tr><td>Brunei Darussalam</td><td>finance</td><td>1</td></tr><tr><td>Brunei Darussalam</td><td>diy-and-crafts</td><td>1</td></tr><tr><td>Bulgaria</td><td>christmas</td><td>12</td></tr><tr><td>Burkina Faso</td><td>quotes</td><td>6</td></tr><tr><td>Burundi</td><td>mens-fashion</td><td>5</td></tr><tr><td>Cambodia</td><td>vehicles</td><td>9</td></tr><tr><td>Cameroon</td><td>travel</td><td>5</td></tr><tr><td>Canada</td><td>education</td><td>1</td></tr><tr><td>Canada</td><td>travel</td><td>1</td></tr><tr><td>Canada</td><td>tattoos</td><td>1</td></tr><tr><td>Canada</td><td>mens-fashion</td><td>1</td></tr><tr><td>Canada</td><td>art</td><td>1</td></tr><tr><td>Canada</td><td>christmas</td><td>1</td></tr><tr><td>Cape Verde</td><td>education</td><td>4</td></tr><tr><td>Cayman Islands</td><td>mens-fashion</td><td>1</td></tr><tr><td>Cayman Islands</td><td>travel</td><td>1</td></tr><tr><td>Cayman Islands</td><td>art</td><td>1</td></tr><tr><td>Central African Republic</td><td>christmas</td><td>4</td></tr><tr><td>Chad</td><td>mens-fashion</td><td>2</td></tr><tr><td>Chad</td><td>diy-and-crafts</td><td>2</td></tr><tr><td>Chile</td><td>mens-fashion</td><td>2</td></tr><tr><td>China</td><td>finance</td>< ...

# %%
#YOU NEED TO RUN THIS IMMEDIATELY AFTER THE SQL QUERY TO KEEP IT
task4_df = _sqldf 
task4_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Task 5 Find how many posts each category had between 2018 and 2022.
#
# Your query should return a DataFrame that contains the following columns:
#
# post_year, a new column that contains only the year from the timestamp column
#
# category
#
# category_count, a new column containing the desired query output

# %%
df_pin.show(1)
df_geo.show(1)
df_user.show(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# index|           unique_id|               title|         description|follower_count|         poster_name|            tag_list|is_image_or_video|           image_src|       save_location|      category|
# +-----+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
#  4387|ae5e7377-f1bd-4ac...|Βάπτιση: H παραμυ...|Το όνομα που επέλ...|             4|Manosbojana Katsa...|Diy Flowers,Flowe...|            image|https://i.pinimg....|/data/event-planning|event-planning|
# +-----+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# only showing top 1 row
#
# +--------------------+----+--------+---------+-------------------+
#              country| ind|latitude|longitude|          timestamp|
# +--------------------+----+--------+---------+-------------------+
# British Indian Oc...|9455|-82.9272| -150.346|2022-03-15 01:46:32|
# +--------------------+----+--------+---------+-------------------+
# only showing top 1 row
#
# +---+-------------------+-----------+----+---------+
# age|        date_joined| first_name| ind|last_name|
# +---+-------------------+-----------+----+---------+
#  42|2017-02-18 00:31:22|Christopher|6353|Hernandez|
# +---+-------------------+-----------+----+---------+
# only showing top 1 row
#
# </div>

# %% [markdown]
# Ok, so we need to join df_pin and df_geo
# then we need to extract the year from the

# %%
# %sql
SELECT 
  EXTRACT(YEAR FROM timestamp) AS year,
  category,
  count(category) AS category_count
FROM 
  pin_table
JOIN 
  geo_table ON geo_table.ind = pin_table.ind
WHERE 
  EXTRACT(YEAR FROM timestamp) BETWEEN 2018 AND 2022
GROUP BY 
  year, category
ORDER BY 
  year, category
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>category</th><th>category_count</th></tr></thead><tbody><tr><td>2018</td><td>art</td><td>30</td></tr><tr><td>2018</td><td>beauty</td><td>26</td></tr><tr><td>2018</td><td>christmas</td><td>41</td></tr><tr><td>2018</td><td>diy-and-crafts</td><td>43</td></tr><tr><td>2018</td><td>education</td><td>32</td></tr><tr><td>2018</td><td>event-planning</td><td>23</td></tr><tr><td>2018</td><td>finance</td><td>28</td></tr><tr><td>2018</td><td>home-decor</td><td>22</td></tr><tr><td>2018</td><td>mens-fashion</td><td>31</td></tr><tr><td>2018</td><td>quotes</td><td>42</td></tr><tr><td>2018</td><td>tattoos</td><td>23</td></tr><tr><td>2018</td><td>travel</td><td>36</td></tr><tr><td>2018</td><td>vehicles</td><td>24</td></tr><tr><td>2019</td><td>art</td><td>45</td></tr><tr><td>2019</td><td>beauty</td><td>15</td></tr><tr><td>2019</td><td>christmas</td><td>35</td></tr><tr><td>2019</td><td>diy-and-crafts</td><td>32</td></tr><tr><td>2019</td><td>education</td><td>36</td></tr><tr><td>2019</td><td>event-planning</td><td>26</td></tr><tr><td>2019</td><td>finance</td><td>22</td></tr><tr><td>2019</td><td>home-decor</td><td>19</td></tr><tr><td>2019</td><td>mens-fashion</td><td>26</td></tr><tr><td>2019</td><td>quotes</td><td>25</td></tr><tr><td>2019</td><td>tattoos</td><td>21</td></tr><tr><td>2019</td><td>travel</td><td>35</td></tr><tr><td>2019</td><td>vehicles</td><td>35</td></tr><tr><td>2020</td><td>art</td><td>44</td></tr><tr><td>2020</td><td>beauty</td><td>25</td></tr><tr><td>2020</td><td>christmas</td><td>36</td></tr><tr><td>2020</td><td>diy-and-crafts</td><td>23</td></tr><tr><td>2020</td><td>education</td><td>23</td></tr><tr><td>2020</td><td>event-planning</td><td>31</td></tr><tr><td>2020</td><td>finance</td><td>37</td></tr><tr><td>2020</td><td>home-decor</td><td>35</td></tr><tr><td>2020</td><td>mens-fashion</td><td>37</td></tr><tr><td>2020</td><td>quotes</td><td>23</td></tr><tr><td>2020</td><td>tattoos</td><td>21</td></tr><tr><td>2020</td><td>travel</td><td>38</td></tr><tr><td>2020</td><td>vehicles</td><td>17</td></tr><tr><td>2021</td><td>art</td><td>47</td></tr><tr><td>2021</td><td>beauty</td><td>16</td></tr><tr><td>2021</td><td>christmas</td><td>30</td></tr><tr><td>2021</td><td>diy-and-crafts</td><td>30</td></tr><tr><td>2021</td><td>education</td><td>40</td></tr><tr><td>2021</td><td>event-planning</td><td>30</td></tr><tr><td>2021</td><td>finance</td><td>40</td></tr><tr><td>2021</td><td>home-decor</td><td>18</td></tr><tr><td>2021</td><td>mens-fashion</td><td>26</td></tr><tr><td>2021</td><td>quotes</td><td>41</td></tr><tr><td>2021</td><td>tattoos</td><td>40</td></tr><tr><td>2021</td><td>travel</td><td>30</td></tr><tr><td>2021</td><td>vehicles</td><td>35</td></tr><tr><td>2022</td><td>art</td><td>26</td></tr><tr><td>2022</td><td>beauty</td><td>34</td></tr><tr><td>2022</td><td>christmas</td><td>44</td></tr><tr><td>2022</td><td>diy-and-crafts</td><td>26</td></tr><tr><td>2022</td><td>education</td><td>19</td></tr><tr><td>2022</td><td>event-planning</td><td>14</td></tr><tr><td>2022</td><td>finance</td><td>23</td></tr><tr><td>2022</td><td>home-decor</td><td>19</td></tr><tr><td>2022</td><td>mens-fashion</td><td>23</td></tr><tr><td>2022</td><td>quotes</td><td>29</td></tr><tr><td>2022</td><td>tattoos</td><td>29</td></tr><tr><td>2022</td><td>travel</td><td>26</td></tr><tr><td>2022</td><td>vehicles</td><td>19</td></tr></tbody></table></div>

# %%
## run after Task 5 SQL to access in Databricks
task5_df = _sqldf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Task 6: Find the user with the most followers in each country
#
# ####Step 1: For each country find the user with the most followers.
#
# Your query should return a DataFrame that contains the following columns:
#
# - country
# - poster_name
# - follower_count
#
# ####Step 2: Based on the above query, find the country with the user with most followers.
#
# Your query should return a DataFrame that contains the following columns:
#
# - country
# - follower_count
#
# This DataFrame should have only one entry.

# %% [markdown]
# So, we need to join user and geo table,
# and then we partition then table to rank the number of users for each country

# %%
df_pin.show(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
#  ind|           unique_id|               title|         description|follower_count|         poster_name|            tag_list|is_image_or_video|           image_src|       save_location|      category|
# +----+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# 4387|ae5e7377-f1bd-4ac...|Βάπτιση: H παραμυ...|Το όνομα που επέλ...|             4|Manosbojana Katsa...|Diy Flowers,Flowe...|            image|https://i.pinimg....|/data/event-planning|event-planning|
# +----+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# only showing top 1 row
#
# </div>

# %%
# %sql
--Task 6, Part 1

WITH initial_table AS (
  SELECT 
    country, 
    user_name AS poster_name,
    follower_count,
    RANK() OVER (
      PARTITION BY country
      ORDER BY follower_count DESC
    ) rank_order
  FROM 
    geo_table 
      JOIN user_table ON user_table.ind = geo_table.ind
      JOIN pin_table ON pin_table.ind = user_table.ind
)

SELECT DISTINCT country,
  poster_name,
  follower_count
FROM 
  initial_table
WHERE
  rank_order = 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>poster_name</th><th>follower_count</th></tr></thead><tbody><tr><td>Afghanistan</td><td>Amanda Carlson</td><td>3000000</td></tr><tr><td>Albania</td><td>Aaron Anderson</td><td>5000000</td></tr><tr><td>Algeria</td><td>Cynthia Adams</td><td>5000000</td></tr><tr><td>American Samoa</td><td>Abigail Bates</td><td>8000000</td></tr><tr><td>Andorra</td><td>Alison Bell</td><td>1000000</td></tr><tr><td>Angola</td><td>April Brown</td><td>8000000</td></tr><tr><td>Anguilla</td><td>Corey Andrews</td><td>92000</td></tr><tr><td>Antarctica (the territory South of 60 deg S)</td><td>Benjamin Campbell</td><td>1000000</td></tr><tr><td>Antigua and Barbuda</td><td>Ann Chung</td><td>1000000</td></tr><tr><td>Argentina</td><td>Diana Barry</td><td>2000000</td></tr><tr><td>Armenia</td><td>Andrew Baker</td><td>892000</td></tr><tr><td>Aruba</td><td>Debra Becker</td><td>874000</td></tr><tr><td>Australia</td><td>Alicia Burnett</td><td>2000000</td></tr><tr><td>Austria</td><td>Alan Burton</td><td>813000</td></tr><tr><td>Azerbaijan</td><td>Amanda Ball</td><td>6000000</td></tr><tr><td>Bahamas</td><td>Christopher Brown</td><td>948000</td></tr><tr><td>Bahrain</td><td>Christy Anderson</td><td>337000</td></tr><tr><td>Bangladesh</td><td>Brian Hansen</td><td>4000000</td></tr><tr><td>Barbados</td><td>Brett Bryant</td><td>410000</td></tr><tr><td>Belarus</td><td>Alexandra Brown</td><td>648000</td></tr><tr><td>Belgium</td><td>Frank Clark</td><td>944000</td></tr><tr><td>Belize</td><td>Becky Brady</td><td>267000</td></tr><tr><td>Benin</td><td>Ann Acevedo</td><td>113000</td></tr><tr><td>Bermuda</td><td>David Moss</td><td>46000</td></tr><tr><td>Bhutan</td><td>Angel Brown</td><td>130000</td></tr><tr><td>Bolivia</td><td>Aaron Baldwin</td><td>328000</td></tr><tr><td>Bosnia and Herzegovina</td><td>Angela Becker</td><td>388000</td></tr><tr><td>Botswana</td><td>Alicia Benjamin</td><td>3000000</td></tr><tr><td>Bouvet Island (Bouvetoya)</td><td>Amy Brown</td><td>5000000</td></tr><tr><td>Brazil</td><td>Barbara Barton</td><td>42000</td></tr><tr><td>British Indian Ocean Territory (Chagos Archipelago)</td><td>Calvin Baker</td><td>248000</td></tr><tr><td>British Virgin Islands</td><td>Alex Bean</td><td>245000</td></tr><tr><td>Brunei Darussalam</td><td>Brad Abbott</td><td>277000</td></tr><tr><td>Bulgaria</td><td>Andrew Alvarez</td><td>912000</td></tr><tr><td>Burkina Faso</td><td>Andrea Burke</td><td>6000000</td></tr><tr><td>Burundi</td><td>Donna Carroll</td><td>620000</td></tr><tr><td>Cambodia</td><td>Andrew Miller</td><td>2000000</td></tr><tr><td>Cameroon</td><td>Daniel Dorsey</td><td>123000</td></tr><tr><td>Canada</td><td>Jacob Alvarez</td><td>258000</td></tr><tr><td>Cape Verde</td><td>Alexander Perez</td><td>178000</td></tr><tr><td>Cayman Islands</td><td>Alexandria Davis</td><td>1000000</td></tr><tr><td>Central African Republic</td><td>Annette Forbes</td><td>868000</td></tr><tr><td>Chad</td><td>Billy Armstrong</td><td>226000</td></tr><tr><td>Chile</td><td>Nathan Stanton</td><td>19000</td></tr><tr><td>China</td><td>Michael Brooks</td><td>127000</td></tr><tr><td>Christmas Island</td><td>Barry Lynn</td><td>3000000</td></tr><tr><td>Cocos (Keeling) Islands</td><td>Cesar Miller</td><td>709000</td></tr><tr><td>Colombia</td><td>Kevin Rodriguez</td><td>239000</td></tr><tr><td>Comoros</td><td>Paul Gonzalez</td><td>4000000</td></tr><tr><td>Congo</td><td>Albert Jackson</td><td>410000</td></tr><tr><td>Cook Islands</td><td>Brandon Buchanan</td><td>1000</td></tr><tr><td>Cook Islands</td><td>Daniel Reyes</td><td>1000</td></tr><tr><td>Costa Rica</td><td>Briana Bryant</td><td>2000000</td></tr><tr><td>Cote d'Ivoire</td><td>Brian Dalton</td><td>565000</td></tr><tr><td>Croatia</td><td>James Sharp</td><td>134000</td></tr><tr><td>Cuba</td><td>David Acosta</td><td>1000000</td></tr><tr><td>Cyprus</td><td>David Bell</td><td>117000</td></tr><tr><td>Czech Republic</td><td>Jacob Castro ...

# %%
country_user_table_df = _sqldf
country_user_table_df.createOrReplaceTempView('country_user_table')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

--Task 6, Part 2
-- Find the country with the user with the most followers
WITH top_country_user AS (
  SELECT 
    country, 
    follower_count
  FROM 
    country_user_table
  GROUP BY follower_count, country
  ORDER BY follower_count DESC
  LIMIT 1
)
SELECT country,
  follower_count
FROM 
  top_country_user;

  -- this will output only one entry as requested. However, there may be more than one country that has the highest number of users if there is a draw. If we wanted that, we would have used RANK()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>follower_count</th></tr></thead><tbody><tr><td>American Samoa</td><td>8000000</td></tr></tbody></table></div>

# %%
task6_part2_df = _sqldf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Task 7: Find the most popular category for different age groups
#
# What is the most popular category people post to based on the following age groups:
#
#   - 18-24
#   - 25-35
#   - 36-50
#   - +50
#
# Your query should return a DataFrame that contains the following columns:
#
#   - age_group, a new column based on the original age column
#   - category
#   category_count, a new column containing the desired query output

# %% [markdown]
# Category is in pin_table and age is in user, so we need to join those tables
# Then we need to create a temporary table where we assign someone a category of one of 4 ages
# Then we partition the table based on these categories and create a "category count" column that we rank descending,
# and we return where rank is 1

# %%
# %sql
--first subquery is to create the age group 
-- WITH create_age_cat AS
--   (
--     SELECT category,
--     CASE
--       WHEN age >= 18 AND age <=24 THEN '18-24'
--       WHEN age >= 25 AND age <=35 THEN '25-35'
--       WHEN age >= 36 AND age <=50 THEN '36-50'
--       WHEN age > 50 THEN '+50'
--       ELSE NULL
--     END 
--       AS age_group
--   FROM pin_table JOIN user_table ON pin_table.ind = user_table.ind
--   ),
--   count_cat AS 
--   (
--     SELECT age_group, 
--       COUNT(category) AS category_count
--     FROM 
--       create_age_cat
--     GROUP BY 
--       age_group
--   )


-- SELECT age_group, 
--   category_count,
--   RANK() OVER (PARTITION BY age_group ORDER BY category_count)
-- FROM count_cat;  


WITH create_age_cat AS
  (
    SELECT category,
    CASE
      WHEN age >= 18 AND age <=24 THEN '18-24'
      WHEN age >= 25 AND age <=35 THEN '25-35'
      WHEN age >= 36 AND age <=50 THEN '36-50'
      WHEN age > 50 THEN '50+'
      ELSE NULL
    END 
      AS age_group
  FROM pin_table JOIN user_table ON pin_table.ind = user_table.ind
  ),
  count_cat AS (
    SELECT age_group, category,
      COUNT(category) AS category_count
    FROM 
      create_age_cat
    GROUP BY 
      age_group, category
  ),
  ranked_table AS (
    SELECT age_group, category,
    category_count,
    RANK() OVER (PARTITION BY age_group ORDER BY category_count DESC) ranked
  FROM  
    count_cat
  )

  SELECT
   age_group, 
   category,
   category_count
  FROM 
    ranked_table
  WHERE 
    ranked = 1
  ORDER BY age_group;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age_group</th><th>category</th><th>category_count</th></tr></thead><tbody><tr><td>18-24</td><td>art</td><td>109</td></tr><tr><td>25-35</td><td>travel</td><td>62</td></tr><tr><td>36-50</td><td>quotes</td><td>50</td></tr><tr><td>50+</td><td>vehicles</td><td>19</td></tr></tbody></table></div>

# %%
task7_df = _sqldf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Task 8: Find the median follower count for the different age groups
#
# What is the median follower count for users in the following age groups:
#
# - 18-24
# - 25-35
# - 36-50
# - 50+
#
# Your query should return a DataFrame that contains the following columns:
#
# - age_group, a new column based on the original age column
# - median_follower_count, a new column containing the desired query output

# %% [markdown]
# We divide the follower counts into age categories using a case statement.
# Then we count the rows per partition and divide the total of followers by the total (is the median?) If odd number, it is the middle of the list. If even, it is the middle two numbers divided by 2.
#
# *** We actually used percentile to calculate this. Not the best, but it is approx and i think the data needs more cleaning.

# %%
# %sql
WITH follower_table AS (
  SELECT follower_count,
    CASE
      WHEN age >= 18 AND age <=24 THEN '18-24'
      WHEN age >= 25 AND age <=35 THEN '25-35'
      WHEN age >= 36 AND age <=50 THEN '36-50'
      WHEN age > 50 THEN '50+'
      ELSE NULL
    END 
      AS age_group
  FROM pin_table JOIN user_table ON pin_table.ind = user_table.ind
)

SELECT DISTINCT age_group, 
  --PERCENTILE_CONT(.5) WITHIN GROUP (ORDER BY follower_count) OVER(PARTITION BY age_group) median_follower_count
  approx_percentile(follower_count, 0.5) OVER(PARTITION BY age_group) median_follower_count
  
FROM
  follower_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age_group</th><th>median_follower_count</th></tr></thead><tbody><tr><td>18-24</td><td>108000</td></tr><tr><td>25-35</td><td>24000</td></tr><tr><td>36-50</td><td>7000</td></tr><tr><td>50+</td><td>908</td></tr></tbody></table></div>

# %%
task8_df = _sqldf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
-- to check result the figures above should be the middle rows of this outpit:
SELECT follower_count,
    CASE
      WHEN age >= 18 AND age <=24 THEN '18-24'
      WHEN age >= 25 AND age <=35 THEN '25-35'
      WHEN age >= 36 AND age <=50 THEN '36-50'
      WHEN age > 50 THEN '50+'
      ELSE NULL
    END 
      AS age_group
  FROM pin_table JOIN user_table ON pin_table.ind = user_table.ind
  ORDER BY age_group, follower_count
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>follower_count</th><th>age_group</th></tr></thead><tbody><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>null</td><td>18-24</td></tr><tr><td>0</td><td>18-24</td></tr><tr><td>0</td><td>18-24</td></tr><tr><td>0</td><td>18-24</td></tr><tr><td>0</td><td>18-24</td></tr><tr><td>1</td><td>18-24</td></tr><tr><td>1</td><td>18-24</td></tr><tr><td>4</td><td>18-24</td></tr><tr><td>4</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>5</td><td>18-24</td></tr><tr><td>7</td><td>18-24</td></tr><tr><td>8</td><td>18-24</td></tr><tr><td>19</td><td>18-24</td></tr><tr><td>25</td><td>18-24</td></tr><tr><td>25</td><td>18-24</td></tr><tr><td>27</td><td>18-24</td></tr><tr><td>27</td><td>18-24</td></tr><tr><td>27</td><td>18-24</td></tr><tr><td>27</td><td>18-24</td></tr><tr><td>27</td><td>18-24</td></tr><tr><td>27</td><td>18-24</td></tr><tr><td>27</td><td>18-24</td></tr><tr><td>27</td><td>18-24</td></tr><tr><td>39</td><td>18-24</td></tr><tr><td>39</td><td>18-24</td></tr><tr><td>39</td><td>18-24</td></tr><tr><td>39</td><td>18-24</td></tr><tr><td>65</td><td>18-24</td></tr><tr><td>78</td><td>18-24</td></tr><tr><td>112</td><td>18-24</td></tr><tr><td>159</td><td>18-24</td></tr><tr><td>159</td><td>18-24</td></tr><tr><td>159</td><td>18-24</td></tr><tr><td>159</td><td>18-24</td></tr><tr><td>159</td><td>18-24</td></tr><tr><td>159</td><td>18-24</td></tr><tr><td>184</td><td>18-24</td></tr><tr><td>191</td><td>18-24</td></tr><tr><td>221</td><td>18-24</td></tr><tr><td>221</td><td>18-24</td></tr><tr><td>221</td><td>18-24</td></tr><tr><td>221</td><td>18-24</td></tr><tr><td>240</td><td>18-24</td></tr><tr><td>265</td><td>18-24</td></tr><tr><td>265</td><td>18-24</td></tr><tr><td>305</td><td>18-24</td></tr><tr><td>313</td><td>18-24</td></tr><tr><td>313</td><td>18-24</td></tr><tr><td>313</td><td>18-24</td></tr><tr><td>313</td><td>18-24</td></tr><tr><td>359</td><td>18-24</td></tr><tr><td>376</td><td>18-24</td></tr><tr><td>394</td><td>18-24</td></tr><tr><td>771</td><td>18-24</td></tr><tr><td>778</td><td>18-24</td></tr><tr><td>849</td><td>18-24</td></tr><tr><td>873</td><td>18-24</td></tr><tr><td>884</td><td>18-24</td></tr><tr><td>940</td><td>18-24</td></tr><tr><td>940</td><td>18-24</td></tr><tr><td>940</td><td>18-24</td></tr><tr><td>940</td><td>18-24</td></tr><tr><td>960</td><td>18-24</td></tr><tr><td>1000</td><td>18-24</td></tr><tr><td>1000</td><td>18-24</td></tr><tr><td>1000</td><td>18-24</td></tr><tr><td>1000</td><td>18-24</td></tr><tr><td>1000</td><td>18-24</td></tr><tr><td>1000</td><td>18-24</td></tr><tr><td>1000</td><td>18-24</td></tr><tr><td>1000</td><td>18-24</ ...

# %% [markdown]
# ### Task 9: Find how many users have joined each year
#
# Find how many users have joined between 2015 and 2020.
#
# Your query should return a DataFrame that contains the following columns:
#
# - post_year, a new column that contains only the year from the timestamp column
# - number_users_joined, a new column containing the desired query output

# %%
# %sql
SELECT EXTRACT(YEAR FROM date_joined) AS post_year,
    COUNT(user_name) AS number_users_joined
FROM 
    user_table
GROUP BY 
    EXTRACT(YEAR FROM date_joined)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>post_year</th><th>number_users_joined</th></tr></thead><tbody><tr><td>2015</td><td>644</td></tr><tr><td>2016</td><td>720</td></tr><tr><td>2017</td><td>260</td></tr></tbody></table></div>

# %% [markdown]
# ### Task 10: Find the median follower count of users based on their joining year
# Find the median follower count of users have joined between 2015 and 2020.
#
# Your query should return a DataFrame that contains the following columns:
#
# - post_year, a new column that contains only the year from the timestamp column
# - median_follower_count, a new column containing the desired query output

# %% [markdown]
# so, we need to look at all the follower counts based on user as they are divided by year, and then find the median for that

# %%
df_pin.show(1)
df_user.show(1)
df_geo.show(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
#  ind|           unique_id|               title|         description|follower_count|         poster_name|            tag_list|is_image_or_video|           image_src|       save_location|      category|
# +----+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# 4387|ae5e7377-f1bd-4ac...|Βάπτιση: H παραμυ...|Το όνομα που επέλ...|             4|Manosbojana Katsa...|Diy Flowers,Flowe...|            image|https://i.pinimg....|/data/event-planning|event-planning|
# +----+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------+
# only showing top 1 row
#
# +----+--------------------+---+-------------------+
#  ind|           user_name|age|        date_joined|
# +----+--------------------+---+-------------------+
# 6353|Christopher Herna...| 42|2017-02-18 00:31:22|
# +----+--------------------+---+-------------------+
# only showing top 1 row
#
# +----+--------------------+--------------------+-------------------+
#  ind|             country|         coordinates|          timestamp|
# +----+--------------------+--------------------+-------------------+
# 9455|British Indian Oc...|[-82.9272, -150.346]|2022-03-15 01:46:32|
# +----+--------------------+--------------------+-------------------+
# only showing top 1 row
#
# </div>

# %%
# %sql
WITH year_table AS (
  SELECT EXTRACT(YEAR FROM date_joined) AS post_year,
    follower_count
  FROM 
    user_table JOIN pin_table ON user_table.ind == pin_table.ind
)

SELECT DISTINCT post_year,
 approx_percentile(follower_count, 0.5) OVER(PARTITION BY post_year) median_follower_count
FROM
  year_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>post_year</th><th>median_follower_count</th></tr></thead><tbody><tr><td>2015</td><td>128000</td></tr><tr><td>2016</td><td>19000</td></tr><tr><td>2017</td><td>3000</td></tr></tbody></table></div>

# %%
# %sql

--Check for the median values NULL seems to be an issue for 2015

 SELECT EXTRACT(YEAR FROM date_joined) AS post_year,
    follower_count
  FROM 
    user_table JOIN pin_table ON user_table.ind == pin_table.ind
  ORDER BY 
    post_year, follower_count
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>post_year</th><th>follower_count</th></tr></thead><tbody><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>null</td></tr><tr><td>2015</td><td>0</td></tr><tr><td>2015</td><td>0</td></tr><tr><td>2015</td><td>0</td></tr><tr><td>2015</td><td>0</td></tr><tr><td>2015</td><td>0</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>5</td></tr><tr><td>2015</td><td>7</td></tr><tr><td>2015</td><td>11</td></tr><tr><td>2015</td><td>13</td></tr><tr><td>2015</td><td>21</td></tr><tr><td>2015</td><td>39</td></tr><tr><td>2015</td><td>91</td></tr><tr><td>2015</td><td>121</td></tr><tr><td>2015</td><td>137</td></tr><tr><td>2015</td><td>137</td></tr><tr><td>2015</td><td>137</td></tr><tr><td>2015</td><td>137</td></tr><tr><td>2015</td><td>159</td></tr><tr><td>2015</td><td>159</td></tr><tr><td>2015</td><td>159</td></tr><tr><td>2015</td><td>159</td></tr><tr><td>2015</td><td>159</td></tr><tr><td>2015</td><td>159</td></tr><tr><td>2015</td><td>167</td></tr><tr><td>2015</td><td>184</td></tr><tr><td>2015</td><td>196</td></tr><tr><td>2015</td><td>305</td></tr><tr><td>2015</td><td>326</td></tr><tr><td>2015</td><td>517</td></tr><tr><td>2015</td><td>583</td></tr><tr><td>2015</td><td>873</td></tr><tr><td>2015</td><td>884</td></tr><tr><td>2015</td><td>970</td></tr><tr><td>2015</td><td>1000</td></tr><tr><td>2015</td><td>1000</td></tr><tr><td>2015</td><td>1000</td></tr><tr><td>2015</td><td>1000</td></tr><tr><td>2015</td><td>1000</td></tr><tr><td>2015</td><td>1000</td></tr><tr><td>2015</td><td>2000</td></tr><tr><td>2015</td><td>2000</td></tr><tr><td>2015</td><td>2000</td></tr><tr><td>2015</td><td>2000</td></tr><tr><td>2015</td><td>2000</td></tr><tr><td>2015</td><td>2000</td></tr><tr><td>2015</td><td>2000</td></tr><tr><td>2015</td><td>2000</td></tr><tr><td>2015</td><td>3000</td></tr><tr><td>2015</td><td>3000</td></tr><tr><td>2015</td><td>3000</td></tr><tr><td>2015</td><td>3000</td></tr><tr><td>2015</td><td>3000</td></tr><tr><td>2015</td><td>3000</td></tr><tr><td>2015</td><td>3000</td></tr><tr><td>2015</td><td>3000</td></tr><tr><td>2015</td><td>4000</td></tr><tr><td>2015</td><td>4000</td></tr><tr><td>2015</td><td>4000</td></tr><tr><td>2015</td><td>4000</td></tr><tr><td>2015</td><td>4000</td></tr><tr><td>2015</td><td>4000</td></tr><tr><td>2015</td><td>4000</td></tr><tr><td>2015</td><td>4000</td></tr><tr><td>2015</td><td>5000</td></tr><tr><td>2015</td><td>5000</td></tr><tr><td>2015</td><td>5000</td></tr><tr><td>2015</td><td>5000</td></tr><tr><td>2015</td><td>5000</td></tr><tr><td>2015</td><td>5000</td></tr><tr><td>2015</td><td>5000</td></tr><tr><td>2015</td><td>5000</td></tr><tr><td>2015</td>< ...

# %% [markdown]
# ### Task 11
#
# Find the median follower count of users that have joined between 2015 and 2020, based on which age group they are part of.
#
# Your query should return a DataFrame that contains the following columns:
#
# - age_group, a new column based on the original age column
# - post_year, a new column that contains only the year from the timestamp column
# - median_follower_count, a new column containing the desired query output

# %%
# %sql

WITH follower_table AS (
  SELECT follower_count,
  EXTRACT(YEAR FROM date_joined) AS post_year,
    CASE
      WHEN age >= 18 AND age <=24 THEN '18-24'
      WHEN age >= 25 AND age <=35 THEN '25-35'
      WHEN age >= 36 AND age <=50 THEN '36-50'
      WHEN age > 50 THEN '50+'
      ELSE NULL
    END 
      AS age_group
  FROM pin_table JOIN user_table ON pin_table.ind = user_table.ind
)

SELECT DISTINCT post_year, age_group, 
  --PERCENTILE_CONT(.5) WITHIN GROUP (ORDER BY follower_count) OVER(PARTITION BY age_group) median_follower_count
  approx_percentile(follower_count, 0.5) OVER(PARTITION BY age_group, post_year) median_follower_count
FROM
  follower_table
ORDER BY
  post_year, age_group;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>post_year</th><th>age_group</th><th>median_follower_count</th></tr></thead><tbody><tr><td>2015</td><td>18-24</td><td>228000</td></tr><tr><td>2015</td><td>25-35</td><td>42000</td></tr><tr><td>2015</td><td>36-50</td><td>22000</td></tr><tr><td>2015</td><td>50+</td><td>14000</td></tr><tr><td>2016</td><td>18-24</td><td>37000</td></tr><tr><td>2016</td><td>25-35</td><td>22000</td></tr><tr><td>2016</td><td>36-50</td><td>9000</td></tr><tr><td>2016</td><td>50+</td><td>504</td></tr><tr><td>2017</td><td>18-24</td><td>5000</td></tr><tr><td>2017</td><td>25-35</td><td>5000</td></tr><tr><td>2017</td><td>36-50</td><td>2000</td></tr><tr><td>2017</td><td>50+</td><td>1000</td></tr></tbody></table></div>

# %%
# %sql
-- Test the results

  SELECT follower_count,
  EXTRACT(YEAR FROM date_joined) AS post_year,
    CASE
      WHEN age >= 18 AND age <=24 THEN '18-24'
      WHEN age >= 25 AND age <=35 THEN '25-35'
      WHEN age >= 36 AND age <=50 THEN '36-50'
      WHEN age > 50 THEN '50+'
      ELSE NULL
    END 
      AS age_group
  FROM pin_table JOIN user_table ON pin_table.ind = user_table.ind
  ORDER BY post_year, age_group, follower_count
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>follower_count</th><th>post_year</th><th>age_group</th></tr></thead><tbody><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>null</td><td>2015</td><td>18-24</td></tr><tr><td>0</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>5</td><td>2015</td><td>18-24</td></tr><tr><td>159</td><td>2015</td><td>18-24</td></tr><tr><td>159</td><td>2015</td><td>18-24</td></tr><tr><td>159</td><td>2015</td><td>18-24</td></tr><tr><td>159</td><td>2015</td><td>18-24</td></tr><tr><td>159</td><td>2015</td><td>18-24</td></tr><tr><td>159</td><td>2015</td><td>18-24</td></tr><tr><td>184</td><td>2015</td><td>18-24</td></tr><tr><td>305</td><td>2015</td><td>18-24</td></tr><tr><td>873</td><td>2015</td><td>18-24</td></tr><tr><td>884</td><td>2015</td><td>18-24</td></tr><tr><td>1000</td><td>2015</td><td>18-24</td></tr><tr><td>2000</td><td>2015</td><td>18-24</td></tr><tr><td>4000</td><td>2015</td><td>18-24</td></tr><tr><td>4000</td><td>2015</td><td>18-24</td></tr><tr><td>4000</td><td>2015</td><td>18-24</td></tr><tr><td>4000</td><td>2015</td><td>18-24</td></tr><tr><td>4000</td><td>2015</td><td>18-24</td></tr><tr><td>4000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</td><td>18-24</td></tr><tr><td>5000</td><td>2015</ ...

# %%
# from pyspark.sql.window import Window

# #result = result.createOrReplaceTempView("result_table")

# # result = spark.sql("SELECT DISTINCT ON (country) country, category, count FROM result_table ORDER BY country, count DESC NULLS LAST;")

# window = Window.partitionBy("country").orderBy("count")

# # res = result.withColumn("country").over(window)
# result.withColumn("rank", rank().over(window)).withColumn("max", max('count').over(window)).sort(desc("count")).show()
# #res.show()
# result.select("country", "category", first(count))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# result.select("country", "category", first(count))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2938465585006629&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>result<span class="ansi-blue-fg">.</span>select<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;country&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;category&#34;</span><span class="ansi-blue-fg">,</span> first<span class="ansi-blue-fg">(</span>count<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/functions.py</span> in <span class="ansi-cyan-fg">first</span><span class="ansi-blue-fg">(col, ignorenulls)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1112</span>     &#34;&#34;&#34;
# <span class="ansi-green-intense-fg ansi-bold">   1113</span>     sc <span class="ansi-blue-fg">=</span> SparkContext<span class="ansi-blue-fg">.</span>_active_spark_context
# <span class="ansi-green-fg">-&gt; 1114</span><span class="ansi-red-fg">     </span>jc <span class="ansi-blue-fg">=</span> sc<span class="ansi-blue-fg">.</span>_jvm<span class="ansi-blue-fg">.</span>functions<span class="ansi-blue-fg">.</span>first<span class="ansi-blue-fg">(</span>_to_java_column<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> ignorenulls<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1115</span>     <span class="ansi-green-fg">return</span> Column<span class="ansi-blue-fg">(</span>jc<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1116</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/column.py</span> in <span class="ansi-cyan-fg">_to_java_column</span><span class="ansi-blue-fg">(col)</span>
# <span class="ansi-green-intense-fg ansi-bold">     44</span>         jcol <span class="ansi-blue-fg">=</span> _create_column_from_name<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     45</span>     <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 46</span><span class="ansi-red-fg">         raise TypeError(
# </span><span class="ansi-green-intense-fg ansi-bold">     47</span>             <span class="ansi-blue-fg">&#34;Invalid argument, not a string or column: &#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">     48</span>             <span class="ansi-blue-fg">&#34;{0} of type {1}. &#34;</span>
#
# <span class="ansi-red-fg">TypeError</span>: Invalid argument, not a string or column: &lt;function count at 0x7f12f0120c10&gt; of type &lt;class &#39;function&#39;&gt;. For column literals, use &#39;lit&#39;, &#39;array&#39;, &#39;struct&#39; or &#39;create_map&#39; function.</div>
